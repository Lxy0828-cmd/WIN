# %%
import pandas as pd
import glob
import os
import torch
import numpy as np
from datetime import datetime
from scipy.stats import pearsonr

# 获取所有 CSV 文件
data_dir = 'NASDAQ/'
csv_files = glob.glob(os.path.join(data_dir, 'NASDAQ_*_30Y.csv'))

# 加载公司数据
companies_data = {}
for f in csv_files:
    try:
        company_name = os.path.basename(f).split('_')[1]
        df = pd.read_csv(f)
        df['Date'] = pd.to_datetime(df['Date'], utc=True)
        df['Date'] = df['Date'].dt.tz_convert(None)
        companies_data[company_name] = df
    except Exception as e:
        print(f"Error loading {f}: {e}")

# 定义日期范围
train_start = datetime.strptime('2013-01-01', '%Y-%m-%d')
train_end = datetime.strptime('2013-8-31', '%Y-%m-%d')
val_start = datetime.strptime('2013-9-01', '%Y-%m-%d')
val_end = datetime.strptime('2013-10-31', '%Y-%m-%d')
test_start = datetime.strptime('2013-11-01', '%Y-%m-%d')
test_end = datetime.strptime('2013-12-31', '%Y-%m-%d')

# 按日期范围划分数据
train_data = {}
val_data = {}
test_data = {}
for company, df in companies_data.items():
    train_data[company] = df[(df['Date'] >= train_start) & (df['Date'] <= train_end)][['Date', 'Open', 'High', 'Low', 'Close', 'Volume']].copy()
    val_data[company] = df[(df['Date'] >= val_start) & (df['Date'] <= val_end)][['Date', 'Open', 'High', 'Low', 'Close', 'Volume']].copy()
    test_data[company] = df[(df['Date'] >= test_start) & (df['Date'] <= test_end)][['Date', 'Open', 'High', 'Low', 'Close', 'Volume']].copy()

company_names = list(companies_data.keys())
num_companies = len(company_names)

# %%
def pearsonr_torch(x, y, device='cuda'):
    """
    计算两个序列的皮尔逊相关系数（GPU 加速）
    x, y: shape (seq_len,) 的 PyTorch 张量
    """
    x = x.to(device)
    y = y.to(device)
    mean_x = torch.mean(x)
    mean_y = torch.mean(y)
    xm = x - mean_x
    ym = y - mean_y
    cov_xy = torch.sum(xm * ym)
    std_x = torch.sqrt(torch.sum(xm ** 2))
    std_y = torch.sqrt(torch.sum(ym ** 2))
    corr = cov_xy / (std_x * std_y + 1e-10)  # 避免除以零
    return corr

def create_graph_data(dataset, company_names, seq_len, save_dir, split, corr_threshold=0.7, device='cuda'):
    if not os.path.exists(os.path.join(save_dir, split)):
        os.makedirs(os.path.join(save_dir, split))
    
    num_companies = len(company_names)
    num_windows = 0
    
    # 检查是否有可用的 GPU
    if device == 'cuda' and not torch.cuda.is_available():
        print("警告：未检测到 GPU，使用 CPU 进行计算")
        device = 'cpu'
    
    # 确定最小数据长度
    min_length = min(len(dataset[company]) for company in company_names if not dataset[company].empty)
    if min_length < seq_len + 1:
        print(f"警告：{split} 集数据不足 (min_length={min_length})")
        return 0
    
    # 按行索引生成时间窗口
    for i in range(min_length - seq_len):
        X = []
        Y = []
        valid_companies = []
        close_prices_window = []
        
        # 收集当前窗口的数据
        for j, company in enumerate(company_names):
            df = dataset[company]
            if len(df) < seq_len + 1:
                continue
            
            window_data = df.iloc[i:i+seq_len]
            if len(window_data) == seq_len:
                features = window_data[['Open', 'High', 'Low', 'Close', 'Volume']].values
                X.append(features)
                close_prices_window.append(window_data['Close'].values)
                
                current_close = window_data['Close'].iloc[-1]
                next_data = df.iloc[i+seq_len] if i+seq_len < len(df) else None
                if next_data is not None:
                    next_close = next_data['Close']
                    label = 1 if next_close > current_close else 0
                    Y.append(label)
                    valid_companies.append(j)
        
        # 仅当所有公司数据完整时继续
        if len(X) == num_companies and len(Y) == num_companies:
            # 计算当前窗口的相关性矩阵
            adj_matrix = np.zeros((num_companies, num_companies))
            close_prices_window = np.array(close_prices_window)  # (num_companies, seq_len)
            close_prices_tensor = torch.tensor(close_prices_window, dtype=torch.float32)
            
            for m in range(num_companies):
                for n in range(m + 1, num_companies):
                    if len(close_prices_window[m]) > 1 and len(close_prices_window[n]) > 1:
                        corr = pearsonr_torch(close_prices_tensor[m], close_prices_tensor[n], device)
                        if abs(corr) > corr_threshold:
                            adj_matrix[m, n] = 1
                            adj_matrix[n, m] = 1
            
            # 生成 edge_index
            indices = np.vstack(np.where(adj_matrix > 0))
            edge_index = torch.from_numpy(indices).long()
            
            # 保存图数据
            X = torch.from_numpy(np.array(X, dtype=np.float32))  # (num_companies, seq_len, 5)
            Y = torch.tensor(Y, dtype=torch.long)   # (num_companies,)
            graph_data = {'X': X, 'A': edge_index, 'Y': Y}
            torch.save(graph_data, os.path.join(save_dir, split, f'graph_{num_windows}.pt'))
            num_windows += 1
    
    return num_windows

# 创建并保存图数据
save_dir = './w_7_NASDAQ_graph_data'
seq_len = 7
corr_threshold = 0.7
device = 'cuda' if torch.cuda.is_available() else 'cpu'
train_windows = create_graph_data(train_data, company_names, seq_len, save_dir=save_dir, split='train', corr_threshold=corr_threshold, device=device)
# val_windows = create_graph_data(val_data, company_names, seq_len, save_dir=save_dir, split='val', corr_threshold=corr_threshold, device=device)
# test_windows = create_graph_data(test_data, company_names, seq_len, save_dir=save_dir, split='test', corr_threshold=corr_threshold, device=device)
# print(f"创建了 {train_windows} 个训练图、{val_windows} 个验证图、{test_windows} 个测试图数据文件。")

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GATConv
import os
import time
from sklearn.metrics import f1_score, matthews_corrcoef
import numpy as np

# 检查 GPU 可用性
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

class GATGRUModel(nn.Module):
    def __init__(self, input_dim, gru_hidden_dim, gat_hidden_dim, num_heads, output_dim=2):
        super(GATGRUModel, self).__init__()
        self.gru = nn.GRU(input_dim, gru_hidden_dim, batch_first=True)
        self.gat1 = GATConv(gru_hidden_dim, gat_hidden_dim, heads=num_heads, concat=True)
        self.gat2 = GATConv(gat_hidden_dim * num_heads, gat_hidden_dim, heads=1, concat=True)
        self.fc = nn.Linear(gat_hidden_dim, output_dim)

    def forward(self, x, edge_index):
        gru_out, _ = self.gru(x)
        gru_out = gru_out[:, -1, :]
        gat_out = F.relu(self.gat1(gru_out, edge_index))
        gat_out = self.gat2(gat_out, edge_index)
        out = self.fc(gat_out)
        return out

def train_model(model, save_dir, train_windows, val_windows, test_windows, epochs=50):
    # 将模型移动到 GPU
    model = model.to(device)
    
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.CrossEntropyLoss()
    
    # 加载训练集中第一张图的边索引
    first_graph_data = torch.load(os.path.join(save_dir, 'train', 'graph_0.pt'))
    fixed_edge_index = first_graph_data['A'].to(device)  # 固定边索引并移到 GPU
    
    start_time = time.time()  # 记录训练开始时间
    best_val_accuracy = 0.0  # Track the best validation accuracy
    
    for epoch in range(epochs):
        epoch_start = time.time()  # 记录该 epoch 开始时间

        # 训练
        model.train()
        train_loss, train_accuracy, train_count = 0.0, 0.0, 0
        train_predictions, train_labels = [], []
        
        for i in range(train_windows):
            graph_data = torch.load(os.path.join(save_dir, 'train', f'graph_{i}.pt'))
            X, Y = graph_data['X'], graph_data['Y']
            X, Y = X.to(device), Y.to(device)
            
            optimizer.zero_grad()
            out = model(X, fixed_edge_index)  # 使用固定的边索引
            loss = criterion(out, Y)
            loss.backward()
            optimizer.step()
            
            _, predicted = torch.max(out, 1)
            train_loss += loss.item()
            train_accuracy += (predicted == Y).float().mean().item()
            train_count += 1
            
            train_predictions.extend(predicted.cpu().numpy())
            train_labels.extend(Y.cpu().numpy())
            
        # 验证
        model.eval()
        val_loss, val_accuracy, val_count = 0.0, 0.0, 0
        val_predictions, val_labels = [], []
        
        with torch.no_grad():
            for i in range(val_windows):
                graph_data = torch.load(os.path.join(save_dir, 'val', f'graph_{i}.pt'))
                X, Y = graph_data['X'], graph_data['Y']
                X, Y = X.to(device), Y.to(device)
                
                out = model(X, fixed_edge_index)  # 使用固定的边索引
                loss = criterion(out, Y)
                _, predicted = torch.max(out, 1)
                val_loss += loss.item()
                val_accuracy += (predicted == Y).float().mean().item()
                val_count += 1
                
                val_predictions.extend(predicted.cpu().numpy())
                val_labels.extend(Y.cpu().numpy())
        
        # 平均指标
        avg_train_loss = train_loss / train_count if train_count > 0 else 0
        avg_train_accuracy = train_accuracy / train_count if train_count > 0 else 0
        avg_val_loss = val_loss / val_count if val_count > 0 else 0
        avg_val_accuracy = val_accuracy / val_count if val_count > 0 else 0
        
        # 计算 F1 分数和 MCC
        train_f1 = f1_score(train_labels, train_predictions, average='weighted')
        train_mcc = matthews_corrcoef(train_labels, train_predictions)
        val_f1 = f1_score(val_labels, val_predictions, average='weighted')
        val_mcc = matthews_corrcoef(val_labels, val_predictions)
        
        # 保存最佳模型
        if avg_val_accuracy > best_val_accuracy:
            torch.save(model.state_dict(), 'GAT+GRU_w7_gru64_gat64_head3_static.pt')
            best_val_accuracy = avg_val_accuracy
            
        # 时间统计
        epoch_time = time.time() - epoch_start
        total_time = time.time() - start_time
        
        # 打印指标
        print(f'Epoch {epoch+1}, '
              f'Train Loss: {avg_train_loss:.4f}, Train Acc: {avg_train_accuracy:.4f}, '
              f'Train F1: {train_f1:.4f}, Train MCC: {train_mcc:.4f}, '
              f'Val Loss: {avg_val_loss:.4f}, Val Acc: {avg_val_accuracy:.4f}, '
              f'Val F1: {val_f1:.4f}, Val MCC: {val_mcc:.4f}, '
              f'Epoch Time: {epoch_time:.2f}s, Total Time: {total_time:.2f}s')
    
    print(f'Best Val Accuracy: {best_val_accuracy:.4f}')

# 参数
input_dim = 5  # Open, High, Low, Close, Volume
gru_hidden_dim = 64
gat_hidden_dim = 64
num_heads = 3

save_dir = './w_7_NYSE_graph_data'
train_windows = 137
val_windows = 9
test_windows = 35

# 初始化模型
model = GATGRUModel(input_dim, gru_hidden_dim, gat_hidden_dim, num_heads, output_dim=2)

train_model(model, save_dir, train_windows, val_windows, test_windows)
# Out:
# Using device: cuda
# Epoch 1, Train Loss: 0.7032, Train Acc: 0.5106, Train F1: 0.5083, Train MCC: 0.0156, Val Loss: 0.6965, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 24.91s, Total Time: 24.91s
# Epoch 2, Train Loss: 0.6982, Train Acc: 0.5015, Train F1: 0.4602, Train MCC: -0.0231, Val Loss: 0.6914, Val Acc: 0.5301, Val F1: 0.3675, Val MCC: 0.0010, Epoch Time: 3.38s, Total Time: 28.29s
# Epoch 3, Train Loss: 0.6955, Train Acc: 0.5019, Train F1: 0.4474, Train MCC: -0.0274, Val Loss: 0.6923, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.33s, Total Time: 31.62s
# Epoch 4, Train Loss: 0.6948, Train Acc: 0.5035, Train F1: 0.4426, Train MCC: -0.0259, Val Loss: 0.6922, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.32s, Total Time: 34.94s
# Epoch 5, Train Loss: 0.6937, Train Acc: 0.5170, Train F1: 0.3598, Train MCC: -0.0293, Val Loss: 0.6919, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.27s, Total Time: 38.21s
# Epoch 6, Train Loss: 0.6933, Train Acc: 0.5202, Train F1: 0.3560, Train MCC: 0.0000, Val Loss: 0.6919, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.28s, Total Time: 41.49s
# Epoch 7, Train Loss: 0.6937, Train Acc: 0.5111, Train F1: 0.3826, Train MCC: -0.0337, Val Loss: 0.6915, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.30s, Total Time: 44.79s
# Epoch 8, Train Loss: 0.6933, Train Acc: 0.5202, Train F1: 0.3560, Train MCC: 0.0000, Val Loss: 0.6919, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.32s, Total Time: 48.11s
# Epoch 9, Train Loss: 0.6930, Train Acc: 0.5202, Train F1: 0.3560, Train MCC: 0.0000, Val Loss: 0.6917, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.29s, Total Time: 51.40s
# Epoch 10, Train Loss: 0.6928, Train Acc: 0.5202, Train F1: 0.3560, Train MCC: 0.0000, Val Loss: 0.6916, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.26s, Total Time: 54.66s
# Epoch 11, Train Loss: 0.6927, Train Acc: 0.5202, Train F1: 0.3560, Train MCC: 0.0000, Val Loss: 0.6917, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.27s, Total Time: 57.92s
# Epoch 12, Train Loss: 0.6927, Train Acc: 0.5202, Train F1: 0.3560, Train MCC: 0.0000, Val Loss: 0.6917, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.27s, Total Time: 61.19s
# Epoch 13, Train Loss: 0.6939, Train Acc: 0.5194, Train F1: 0.4715, Train MCC: 0.0183, Val Loss: 0.6916, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.30s, Total Time: 64.49s
# Epoch 14, Train Loss: 0.6931, Train Acc: 0.5202, Train F1: 0.3560, Train MCC: 0.0000, Val Loss: 0.6913, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.30s, Total Time: 67.79s
# Epoch 15, Train Loss: 0.6931, Train Acc: 0.5202, Train F1: 0.3560, Train MCC: 0.0000, Val Loss: 0.6916, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.30s, Total Time: 71.09s
# Epoch 16, Train Loss: 0.6926, Train Acc: 0.5202, Train F1: 0.3560, Train MCC: 0.0000, Val Loss: 0.6916, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.26s, Total Time: 74.35s
# Epoch 17, Train Loss: 0.6926, Train Acc: 0.5202, Train F1: 0.3560, Train MCC: 0.0000, Val Loss: 0.6916, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.28s, Total Time: 77.63s
# Epoch 18, Train Loss: 0.6927, Train Acc: 0.5202, Train F1: 0.3560, Train MCC: 0.0000, Val Loss: 0.6920, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.27s, Total Time: 80.90s
# Epoch 19, Train Loss: 0.6927, Train Acc: 0.5202, Train F1: 0.3560, Train MCC: -0.0020, Val Loss: 0.6917, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.28s, Total Time: 84.19s
# Epoch 20, Train Loss: 0.6926, Train Acc: 0.5202, Train F1: 0.3560, Train MCC: 0.0000, Val Loss: 0.6917, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.30s, Total Time: 87.48s
# Epoch 21, Train Loss: 0.6931, Train Acc: 0.5098, Train F1: 0.3598, Train MCC: -0.0674, Val Loss: 0.6916, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.30s, Total Time: 90.79s
# Epoch 22, Train Loss: 0.6938, Train Acc: 0.5197, Train F1: 0.4509, Train MCC: 0.0156, Val Loss: 0.6916, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.29s, Total Time: 94.08s
# Epoch 23, Train Loss: 0.6924, Train Acc: 0.5202, Train F1: 0.3560, Train MCC: 0.0000, Val Loss: 0.6917, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.28s, Total Time: 97.36s
# Epoch 24, Train Loss: 0.6932, Train Acc: 0.5202, Train F1: 0.3560, Train MCC: 0.0000, Val Loss: 0.6922, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.30s, Total Time: 100.66s
# Epoch 25, Train Loss: 0.6930, Train Acc: 0.5198, Train F1: 0.3563, Train MCC: -0.0103, Val Loss: 0.6917, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.30s, Total Time: 103.96s
# Epoch 26, Train Loss: 0.6924, Train Acc: 0.5202, Train F1: 0.3560, Train MCC: 0.0000, Val Loss: 0.6918, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.27s, Total Time: 107.22s
# Epoch 27, Train Loss: 0.6923, Train Acc: 0.5202, Train F1: 0.3560, Train MCC: 0.0000, Val Loss: 0.6925, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.28s, Total Time: 110.50s
# Epoch 28, Train Loss: 0.6924, Train Acc: 0.5127, Train F1: 0.3793, Train MCC: -0.0297, Val Loss: 0.6922, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.31s, Total Time: 113.81s
# Epoch 29, Train Loss: 0.6922, Train Acc: 0.5177, Train F1: 0.3612, Train MCC: -0.0212, Val Loss: 0.6941, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.29s, Total Time: 117.10s
# Epoch 30, Train Loss: 0.6923, Train Acc: 0.5193, Train F1: 0.3561, Train MCC: -0.0209, Val Loss: 0.6925, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.27s, Total Time: 120.37s
# Epoch 31, Train Loss: 0.6919, Train Acc: 0.5202, Train F1: 0.3560, Train MCC: 0.0000, Val Loss: 0.6921, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.27s, Total Time: 123.64s
# Epoch 32, Train Loss: 0.6926, Train Acc: 0.5202, Train F1: 0.3560, Train MCC: 0.0000, Val Loss: 0.6922, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.26s, Total Time: 126.91s
# Epoch 33, Train Loss: 0.6920, Train Acc: 0.5193, Train F1: 0.3573, Train MCC: -0.0145, Val Loss: 0.6934, Val Acc: 0.5302, Val F1: 0.3674, Val MCC: 0.0085, Epoch Time: 3.30s, Total Time: 130.21s
# Epoch 34, Train Loss: 0.6923, Train Acc: 0.5164, Train F1: 0.3827, Train MCC: -0.0113, Val Loss: 0.6936, Val Acc: 0.5268, Val F1: 0.3699, Val MCC: -0.0318, Epoch Time: 3.28s, Total Time: 133.49s
# Epoch 35, Train Loss: 0.6921, Train Acc: 0.5203, Train F1: 0.3943, Train MCC: 0.0095, Val Loss: 0.6945, Val Acc: 0.5299, Val F1: 0.4219, Val MCC: 0.0161, Epoch Time: 3.30s, Total Time: 136.79s
# Epoch 36, Train Loss: 0.6914, Train Acc: 0.5278, Train F1: 0.4310, Train MCC: 0.0394, Val Loss: 0.6944, Val Acc: 0.5111, Val F1: 0.4669, Val MCC: -0.0151, Epoch Time: 3.28s, Total Time: 140.06s
# Epoch 37, Train Loss: 0.6922, Train Acc: 0.5234, Train F1: 0.4340, Train MCC: 0.0244, Val Loss: 0.6956, Val Acc: 0.5032, Val F1: 0.4541, Val MCC: -0.0368, Epoch Time: 3.25s, Total Time: 143.32s
# Epoch 38, Train Loss: 0.6919, Train Acc: 0.5331, Train F1: 0.4636, Train MCC: 0.0534, Val Loss: 0.6956, Val Acc: 0.4967, Val F1: 0.4617, Val MCC: -0.0433, Epoch Time: 3.30s, Total Time: 146.61s
# Epoch 39, Train Loss: 0.6911, Train Acc: 0.5329, Train F1: 0.4712, Train MCC: 0.0524, Val Loss: 0.6984, Val Acc: 0.4665, Val F1: 0.4375, Val MCC: -0.1062, Epoch Time: 3.29s, Total Time: 149.90s
# Epoch 40, Train Loss: 0.6906, Train Acc: 0.5372, Train F1: 0.4998, Train MCC: 0.0625, Val Loss: 0.6962, Val Acc: 0.4956, Val F1: 0.4578, Val MCC: -0.0478, Epoch Time: 3.31s, Total Time: 153.21s
# Epoch 41, Train Loss: 0.6909, Train Acc: 0.5445, Train F1: 0.4902, Train MCC: 0.0827, Val Loss: 0.6990, Val Acc: 0.4835, Val F1: 0.4437, Val MCC: -0.0771, Epoch Time: 3.30s, Total Time: 156.52s
# Epoch 42, Train Loss: 0.6905, Train Acc: 0.5439, Train F1: 0.4928, Train MCC: 0.0804, Val Loss: 0.6984, Val Acc: 0.4876, Val F1: 0.4421, Val MCC: -0.0719, Epoch Time: 3.31s, Total Time: 159.82s
# Epoch 43, Train Loss: 0.6898, Train Acc: 0.5449, Train F1: 0.5145, Train MCC: 0.0804, Val Loss: 0.7033, Val Acc: 0.4764, Val F1: 0.4542, Val MCC: -0.0784, Epoch Time: 3.31s, Total Time: 163.13s
# Epoch 44, Train Loss: 0.6892, Train Acc: 0.5403, Train F1: 0.4950, Train MCC: 0.0704, Val Loss: 0.7007, Val Acc: 0.4887, Val F1: 0.4755, Val MCC: -0.0444, Epoch Time: 3.31s, Total Time: 166.44s
# Epoch 45, Train Loss: 0.6891, Train Acc: 0.5378, Train F1: 0.5053, Train MCC: 0.0641, Val Loss: 0.7050, Val Acc: 0.4680, Val F1: 0.4500, Val MCC: -0.0924, Epoch Time: 3.34s, Total Time: 169.78s
# Epoch 46, Train Loss: 0.6867, Train Acc: 0.5578, Train F1: 0.5349, Train MCC: 0.1092, Val Loss: 0.7082, Val Acc: 0.4532, Val F1: 0.4367, Val MCC: -0.1221, Epoch Time: 3.63s, Total Time: 173.41s
# Epoch 47, Train Loss: 0.6873, Train Acc: 0.5488, Train F1: 0.5266, Train MCC: 0.0890, Val Loss: 0.7039, Val Acc: 0.4784, Val F1: 0.4424, Val MCC: -0.0857, Epoch Time: 3.63s, Total Time: 177.04s
# Epoch 48, Train Loss: 0.6855, Train Acc: 0.5596, Train F1: 0.5343, Train MCC: 0.1136, Val Loss: 0.7082, Val Acc: 0.4475, Val F1: 0.4441, Val MCC: -0.1168, Epoch Time: 3.63s, Total Time: 180.68s
# Epoch 49, Train Loss: 0.6890, Train Acc: 0.5539, Train F1: 0.5382, Train MCC: 0.1000, Val Loss: 0.7080, Val Acc: 0.4360, Val F1: 0.4364, Val MCC: -0.1298, Epoch Time: 3.65s, Total Time: 184.32s
# Epoch 50, Train Loss: 0.6861, Train Acc: 0.5561, Train F1: 0.5373, Train MCC: 0.1049, Val Loss: 0.7101, Val Acc: 0.4390, Val F1: 0.4203, Val MCC: -0.1545, Epoch Time: 3.63s, Total Time: 187.95s
# Best Val Accuracy: 0.5302

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GATConv
import os
import time
from sklearn.metrics import f1_score, matthews_corrcoef
import numpy as np

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

class GATGRUModel(nn.Module):
    def __init__(self, input_dim, gru_hidden_dim, gat_hidden_dim, num_heads, output_dim=2):
        super(GATGRUModel, self).__init__()
        self.gru = nn.GRU(input_dim, gru_hidden_dim, batch_first=True)
        self.gat1 = GATConv(gru_hidden_dim, gat_hidden_dim, heads=num_heads, concat=True)
        self.gat2 = GATConv(gat_hidden_dim * num_heads, gat_hidden_dim, heads=1, concat=True)
        self.fc = nn.Linear(gat_hidden_dim, output_dim)

    def forward(self, x, edge_index):
        gru_out, _ = self.gru(x)
        gru_out = gru_out[:, -1, :]
        gat_out = F.relu(self.gat1(gru_out, edge_index))
        gat_out = self.gat2(gat_out, edge_index)
        out = self.fc(gat_out)
        return out

input_dim = 5  # Open, High, Low, Close, Volume
gru_hidden_dim = 64
gat_hidden_dim = 64
num_heads = 3

save_dir = './w_7_NYSE_graph_data'
train_windows = 137
val_windows = 9
test_windows = 35

model = GATGRUModel(input_dim, gru_hidden_dim, gat_hidden_dim, num_heads, output_dim=2)
model.load_state_dict(torch.load('GAT+GRU_w7_gru64_gat64_head3_static.pt', map_location=device))
model.to(device)
model.eval()  
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

# 加载训练集中第一张图的边索引
first_graph_data = torch.load(os.path.join(save_dir, 'train', 'graph_0.pt'))
fixed_edge_index = first_graph_data['A'].to(device)  # 固定边索引并移到 GPU

val_loss, val_accuracy, val_count = 0.0, 0.0, 0
val_predictions, val_labels = [], []
with torch.no_grad():
    for i in range(val_windows):
        graph_data = torch.load(os.path.join(save_dir, 'val', f'graph_{i}.pt'))
        X, Y = graph_data['X'], graph_data['Y']
        X, Y = X.to(device), Y.to(device)
        
        out = model(X, fixed_edge_index)  # 使用固定的边索引
        loss = criterion(out, Y)
        _, predicted = torch.max(out, 1)
        val_loss += loss.item()
        val_accuracy += (predicted == Y).float().mean().item()
        val_count += 1
        
        val_predictions.extend(predicted.cpu().numpy())
        val_labels.extend(Y.cpu().numpy())

# 平均指标
avg_val_loss = val_loss / val_count if val_count > 0 else 0
avg_val_accuracy = val_accuracy / val_count if val_count > 0 else 0

# --- Calculate F1-score and MCC ---
val_f1 = f1_score(val_labels, val_predictions, average='weighted')
val_mcc = matthews_corrcoef(val_labels, val_predictions)

# --- Updated print statement with F1 and MCC ---
print(
      f'Val Loss: {avg_val_loss:.4f}, Val Acc: {avg_val_accuracy:.4f}, '
      f'Val F1: {val_f1:.4f}, Val MCC: {val_mcc:.4f} ')
# Out:
# Using device: cuda
# Val Loss: 0.6934, Val Acc: 0.5302, Val F1: 0.3674, Val MCC: 0.0085

# %%
import pandas as pd
import glob
import os
import torch
import numpy as np
from datetime import datetime
from scipy.stats import pearsonr

# 获取所有 CSV 文件
data_dir = 'NASDAQ/'
csv_files = glob.glob(os.path.join(data_dir, 'NASDAQ_*_30Y.csv'))

# 加载公司数据
companies_data = {}
for f in csv_files:
    try:
        company_name = os.path.basename(f).split('_')[1]
        df = pd.read_csv(f)
        df['Date'] = pd.to_datetime(df['Date'], utc=True)
        df['Date'] = df['Date'].dt.tz_convert(None)
        companies_data[company_name] = df
    except Exception as e:
        print(f"Error loading {f}: {e}")

# 定义日期范围
train_start = datetime.strptime('2013-01-01', '%Y-%m-%d')
train_end = datetime.strptime('2013-8-31', '%Y-%m-%d')
val_start = datetime.strptime('2013-9-01', '%Y-%m-%d')
val_end = datetime.strptime('2013-10-31', '%Y-%m-%d')
test_start = datetime.strptime('2013-11-01', '%Y-%m-%d')
test_end = datetime.strptime('2013-12-31', '%Y-%m-%d')

# 按日期范围划分数据
train_data = {}
val_data = {}
test_data = {}
for company, df in companies_data.items():
    train_data[company] = df[(df['Date'] >= train_start) & (df['Date'] <= train_end)][['Date', 'Open', 'High', 'Low', 'Close', 'Volume']].copy()
    val_data[company] = df[(df['Date'] >= val_start) & (df['Date'] <= val_end)][['Date', 'Open', 'High', 'Low', 'Close', 'Volume']].copy()
    test_data[company] = df[(df['Date'] >= test_start) & (df['Date'] <= test_end)][['Date', 'Open', 'High', 'Low', 'Close', 'Volume']].copy()

company_names = list(companies_data.keys())
num_companies = len(company_names)

# %%
def pearsonr_torch(x, y, device='cuda'):
    """
    计算两个序列的皮尔逊相关系数（GPU 加速）
    x, y: shape (seq_len,) 的 PyTorch 张量
    """
    x = x.to(device)
    y = y.to(device)
    mean_x = torch.mean(x)
    mean_y = torch.mean(y)
    xm = x - mean_x
    ym = y - mean_y
    cov_xy = torch.sum(xm * ym)
    std_x = torch.sqrt(torch.sum(xm ** 2))
    std_y = torch.sqrt(torch.sum(ym ** 2))
    corr = cov_xy / (std_x * std_y + 1e-10)  # 避免除以零
    return corr

def create_graph_data(dataset, company_names, seq_len, save_dir, split, corr_threshold=0.7, device='cuda'):
    if not os.path.exists(os.path.join(save_dir, split)):
        os.makedirs(os.path.join(save_dir, split))
    
    num_companies = len(company_names)
    num_windows = 0
    
    # 检查是否有可用的 GPU
    if device == 'cuda' and not torch.cuda.is_available():
        print("警告：未检测到 GPU，使用 CPU 进行计算")
        device = 'cpu'
    
    # 确定最小数据长度
    min_length = min(len(dataset[company]) for company in company_names if not dataset[company].empty)
    if min_length < seq_len + 1:
        print(f"警告：{split} 集数据不足 (min_length={min_length})")
        return 0
    
    # 按行索引生成时间窗口
    for i in range(min_length - seq_len):
        X = []
        Y = []
        valid_companies = []
        close_prices_window = []
        
        # 收集当前窗口的数据
        for j, company in enumerate(company_names):
            df = dataset[company]
            if len(df) < seq_len + 1:
                continue
            
            window_data = df.iloc[i:i+seq_len]
            if len(window_data) == seq_len:
                features = window_data[['Open', 'High', 'Low', 'Close', 'Volume']].values
                X.append(features)
                close_prices_window.append(window_data['Close'].values)
                
                current_close = window_data['Close'].iloc[-1]
                next_data = df.iloc[i+seq_len] if i+seq_len < len(df) else None
                if next_data is not None:
                    next_close = next_data['Close']
                    label = 1 if next_close > current_close else 0
                    Y.append(label)
                    valid_companies.append(j)
        
        # 仅当所有公司数据完整时继续
        if len(X) == num_companies and len(Y) == num_companies:
            # 计算当前窗口的相关性矩阵
            adj_matrix = np.zeros((num_companies, num_companies))
            close_prices_window = np.array(close_prices_window)  # (num_companies, seq_len)
            close_prices_tensor = torch.tensor(close_prices_window, dtype=torch.float32)
            
            for m in range(num_companies):
                for n in range(m + 1, num_companies):
                    if len(close_prices_window[m]) > 1 and len(close_prices_window[n]) > 1:
                        corr = pearsonr_torch(close_prices_tensor[m], close_prices_tensor[n], device)
                        if abs(corr) > corr_threshold:
                            adj_matrix[m, n] = 1
                            adj_matrix[n, m] = 1
            
            # 生成 edge_index
            indices = np.vstack(np.where(adj_matrix > 0))
            edge_index = torch.from_numpy(indices).long()
            
            # 保存图数据
            X = torch.from_numpy(np.array(X, dtype=np.float32))  # (num_companies, seq_len, 5)
            Y = torch.tensor(Y, dtype=torch.long)   # (num_companies,)
            graph_data = {'X': X, 'A': edge_index, 'Y': Y}
            torch.save(graph_data, os.path.join(save_dir, split, f'graph_{num_windows}.pt'))
            num_windows += 1
    
    return num_windows

# 创建并保存图数据
save_dir = './w_7_NASDAQ_graph_data'
seq_len = 7
corr_threshold = 0.7
device = 'cuda' if torch.cuda.is_available() else 'cpu'
train_windows = create_graph_data(train_data, company_names, seq_len, save_dir=save_dir, split='train', corr_threshold=corr_threshold, device=device)
# val_windows = create_graph_data(val_data, company_names, seq_len, save_dir=save_dir, split='val', corr_threshold=corr_threshold, device=device)
# test_windows = create_graph_data(test_data, company_names, seq_len, save_dir=save_dir, split='test', corr_threshold=corr_threshold, device=device)
# print(f"创建了 {train_windows} 个训练图、{val_windows} 个验证图、{test_windows} 个测试图数据文件。")

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GATConv
import os
import time
from sklearn.metrics import f1_score, matthews_corrcoef
import numpy as np

# 检查 GPU 可用性
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

class GATGRUModel(nn.Module):
    def __init__(self, input_dim, gru_hidden_dim, gat_hidden_dim, num_heads, output_dim=2):
        super(GATGRUModel, self).__init__()
        self.gru = nn.GRU(input_dim, gru_hidden_dim, batch_first=True)
        self.gat1 = GATConv(gru_hidden_dim, gat_hidden_dim, heads=num_heads, concat=True)
        self.gat2 = GATConv(gat_hidden_dim * num_heads, gat_hidden_dim, heads=1, concat=True)
        self.fc = nn.Linear(gat_hidden_dim, output_dim)

    def forward(self, x, edge_index):
        gru_out, _ = self.gru(x)
        gru_out = gru_out[:, -1, :]
        gat_out = F.relu(self.gat1(gru_out, edge_index))
        gat_out = self.gat2(gat_out, edge_index)
        out = self.fc(gat_out)
        return out

def train_model(model, save_dir, train_windows, val_windows, test_windows, epochs=600):
    # 将模型移动到 GPU
    model = model.to(device)
    
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.CrossEntropyLoss()
    
    start_time = time.time()  # 记录训练开始时间
    best_val_accuracy = 0.0  # Track the best validation accuracy
    
    for epoch in range(epochs):
        epoch_start = time.time()  # 记录该 epoch 开始时间

        # 训练
        model.train()
        train_loss, train_accuracy, train_count = 0.0, 0.0, 0
        train_predictions, train_labels = [], []
        
        for i in range(train_windows):
            graph_data = torch.load(os.path.join(save_dir, 'train', f'graph_{i}.pt'))
            X, edge_index, Y = graph_data['X'], graph_data['A'], graph_data['Y']
            X, edge_index, Y = X.to(device), edge_index.to(device), Y.to(device)
            
            optimizer.zero_grad()
            out = model(X, edge_index)
            loss = criterion(out, Y)
            loss.backward()
            optimizer.step()
            
            _, predicted = torch.max(out, 1)
            train_loss += loss.item()
            train_accuracy += (predicted == Y).float().mean().item()
            train_count += 1
            
            train_predictions.extend(predicted.cpu().numpy())
            train_labels.extend(Y.cpu().numpy())
            
        # 验证
        model.eval()
        val_loss, val_accuracy, val_count = 0.0, 0.0, 0
        # --- New lists for validation predictions and labels ---
        val_predictions, val_labels = [], []
        
        with torch.no_grad():
            for i in range(val_windows):
                graph_data = torch.load(os.path.join(save_dir, 'val', f'graph_{i}.pt'))
                X, edge_index, Y = graph_data['X'], graph_data['A'], graph_data['Y']
                X, edge_index, Y = X.to(device), edge_index.to(device), Y.to(device)
                
                out = model(X, edge_index)
                loss = criterion(out, Y)
                _, predicted = torch.max(out, 1)
                val_loss += loss.item()
                val_accuracy += (predicted == Y).float().mean().item()
                val_count += 1
                
                val_predictions.extend(predicted.cpu().numpy())
                val_labels.extend(Y.cpu().numpy())
        
        # 平均指标
        avg_train_loss = train_loss / train_count if train_count > 0 else 0
        avg_train_accuracy = train_accuracy / train_count if train_count > 0 else 0
        avg_val_loss = val_loss / val_count if val_count > 0 else 0
        avg_val_accuracy = val_accuracy / val_count if val_count > 0 else 0
        
        # --- Calculate F1-score and MCC ---
        train_f1 = f1_score(train_labels, train_predictions, average='weighted')
        train_mcc = matthews_corrcoef(train_labels, train_predictions)
        val_f1 = f1_score(val_labels, val_predictions, average='weighted')
        val_mcc = matthews_corrcoef(val_labels, val_predictions)
        
        # --- Save model based on validation accuracy ---
        if avg_val_accuracy > best_val_accuracy:
            torch.save(model.state_dict(), 'GAT+GRU_w7_gru64_gat64_head2.pt')
            best_val_accuracy = avg_val_accuracy  # Fixed: Use avg_val_accuracy instead of avg_test_accuracy
            
        # 时间统计
        epoch_time = time.time() - epoch_start
        total_time = time.time() - start_time
        
        # --- Updated print statement with F1 and MCC ---
        print(f'Epoch {epoch+1}, '
              f'Train Loss: {avg_train_loss:.4f}, Train Acc: {avg_train_accuracy:.4f}, '
              f'Train F1: {train_f1:.4f}, Train MCC: {train_mcc:.4f}, '
              f'Val Loss: {avg_val_loss:.4f}, Val Acc: {avg_val_accuracy:.4f}, '
              f'Val F1: {val_f1:.4f}, Val MCC: {val_mcc:.4f}, '
              f'Epoch Time: {epoch_time:.2f}s, Total Time: {total_time:.2f}s')
    
    print(f'Best Val Accuracy: {best_val_accuracy:.4f}')

# 参数
input_dim = 5  # Open, High, Low, Close, Volume
gru_hidden_dim = 64
gat_hidden_dim = 64
num_heads = 2

save_dir = './w_7_NYSE_graph_data'
train_windows = 137
val_windows = 9
test_windows = 35

# 初始化模型
model = GATGRUModel(input_dim, gru_hidden_dim, gat_hidden_dim, num_heads, output_dim=2)

train_model(model, save_dir, train_windows, val_windows, test_windows)
# Out:
# Using device: cuda
# Epoch 1, Train Loss: 0.7035, Train Acc: 0.4966, Train F1: 0.4960, Train MCC: -0.0100, Val Loss: 0.6922, Val Acc: 0.5294, Val F1: 0.3752, Val MCC: -0.0004, Epoch Time: 23.08s, Total Time: 23.08s
# Epoch 2, Train Loss: 0.6972, Train Acc: 0.5006, Train F1: 0.4599, Train MCC: -0.0250, Val Loss: 0.6922, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.09s, Total Time: 26.18s
# Epoch 3, Train Loss: 0.6947, Train Acc: 0.5065, Train F1: 0.4447, Train MCC: -0.0184, Val Loss: 0.6924, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.02s, Total Time: 29.20s
# Epoch 4, Train Loss: 0.6942, Train Acc: 0.4995, Train F1: 0.4159, Train MCC: -0.0476, Val Loss: 0.6925, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 2.79s, Total Time: 31.98s
# Epoch 5, Train Loss: 0.6941, Train Acc: 0.4995, Train F1: 0.3909, Train MCC: -0.0637, Val Loss: 0.6924, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 2.81s, Total Time: 34.80s
# Epoch 6, Train Loss: 0.6936, Train Acc: 0.5203, Train F1: 0.3563, Train MCC: 0.0077, Val Loss: 0.6923, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 2.87s, Total Time: 37.66s
# Epoch 7, Train Loss: 0.6934, Train Acc: 0.5203, Train F1: 0.3562, Train MCC: 0.0076, Val Loss: 0.6923, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 2.85s, Total Time: 40.51s
# Epoch 8, Train Loss: 0.6933, Train Acc: 0.5202, Train F1: 0.3563, Train MCC: 0.0059, Val Loss: 0.6922, Val Acc: 0.5300, Val F1: 0.3675, Val MCC: -0.0025, Epoch Time: 2.95s, Total Time: 43.46s
# Epoch 9, Train Loss: 0.6935, Train Acc: 0.5162, Train F1: 0.3633, Train MCC: -0.0280, Val Loss: 0.6920, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 2.87s, Total Time: 46.33s
# Epoch 10, Train Loss: 0.6937, Train Acc: 0.5060, Train F1: 0.4173, Train MCC: -0.0305, Val Loss: 0.6919, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 2.76s, Total Time: 49.09s
# Epoch 11, Train Loss: 0.6931, Train Acc: 0.5202, Train F1: 0.3563, Train MCC: 0.0037, Val Loss: 0.6920, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 2.82s, Total Time: 51.91s
# Epoch 12, Train Loss: 0.6935, Train Acc: 0.5181, Train F1: 0.3674, Train MCC: -0.0109, Val Loss: 0.6916, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 2.84s, Total Time: 54.75s
# Epoch 13, Train Loss: 0.6929, Train Acc: 0.5202, Train F1: 0.3562, Train MCC: 0.0071, Val Loss: 0.6919, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 2.86s, Total Time: 57.61s
# Epoch 14, Train Loss: 0.6928, Train Acc: 0.5202, Train F1: 0.3562, Train MCC: 0.0071, Val Loss: 0.6919, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 2.71s, Total Time: 60.32s
# Epoch 15, Train Loss: 0.6928, Train Acc: 0.5202, Train F1: 0.3562, Train MCC: 0.0053, Val Loss: 0.6920, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 2.82s, Total Time: 63.15s
# Epoch 16, Train Loss: 0.6927, Train Acc: 0.5204, Train F1: 0.3588, Train MCC: 0.0059, Val Loss: 0.6919, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 2.68s, Total Time: 65.83s
# Epoch 17, Train Loss: 0.6929, Train Acc: 0.5157, Train F1: 0.3617, Train MCC: -0.0338, Val Loss: 0.6919, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 2.82s, Total Time: 68.65s
# Epoch 18, Train Loss: 0.6928, Train Acc: 0.5202, Train F1: 0.3563, Train MCC: 0.0037, Val Loss: 0.6922, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 2.82s, Total Time: 71.47s
# Epoch 19, Train Loss: 0.6928, Train Acc: 0.5179, Train F1: 0.3656, Train MCC: -0.0139, Val Loss: 0.6920, Val Acc: 0.5296, Val F1: 0.3682, Val MCC: -0.0083, Epoch Time: 2.68s, Total Time: 74.15s
# Epoch 20, Train Loss: 0.6928, Train Acc: 0.5243, Train F1: 0.3677, Train MCC: 0.0525, Val Loss: 0.6919, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 2.97s, Total Time: 77.11s
# Epoch 21, Train Loss: 0.6928, Train Acc: 0.5202, Train F1: 0.3562, Train MCC: 0.0068, Val Loss: 0.6918, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.11s, Total Time: 80.22s
# Epoch 22, Train Loss: 0.6927, Train Acc: 0.5202, Train F1: 0.3562, Train MCC: 0.0063, Val Loss: 0.6917, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.17s, Total Time: 83.39s
# Epoch 23, Train Loss: 0.6926, Train Acc: 0.5202, Train F1: 0.3562, Train MCC: 0.0071, Val Loss: 0.6916, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.17s, Total Time: 86.56s
# Epoch 24, Train Loss: 0.6931, Train Acc: 0.5151, Train F1: 0.3554, Train MCC: -0.0575, Val Loss: 0.6916, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.19s, Total Time: 89.75s
# Epoch 25, Train Loss: 0.6928, Train Acc: 0.5202, Train F1: 0.3562, Train MCC: 0.0071, Val Loss: 0.6918, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.18s, Total Time: 92.93s
# Epoch 26, Train Loss: 0.6927, Train Acc: 0.5202, Train F1: 0.3562, Train MCC: 0.0071, Val Loss: 0.6917, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.18s, Total Time: 96.11s
# Epoch 27, Train Loss: 0.6927, Train Acc: 0.5202, Train F1: 0.3562, Train MCC: 0.0071, Val Loss: 0.6917, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.07s, Total Time: 99.18s
# Epoch 28, Train Loss: 0.6927, Train Acc: 0.5202, Train F1: 0.3562, Train MCC: 0.0071, Val Loss: 0.6917, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.18s, Total Time: 102.37s
# Epoch 29, Train Loss: 0.6926, Train Acc: 0.5202, Train F1: 0.3562, Train MCC: 0.0071, Val Loss: 0.6917, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.20s, Total Time: 105.56s
# Epoch 30, Train Loss: 0.6926, Train Acc: 0.5202, Train F1: 0.3562, Train MCC: 0.0071, Val Loss: 0.6917, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.15s, Total Time: 108.72s
# Epoch 31, Train Loss: 0.6926, Train Acc: 0.5202, Train F1: 0.3562, Train MCC: 0.0071, Val Loss: 0.6917, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.24s, Total Time: 111.95s
# Epoch 32, Train Loss: 0.6926, Train Acc: 0.5202, Train F1: 0.3562, Train MCC: 0.0071, Val Loss: 0.6917, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.19s, Total Time: 115.14s
# Epoch 33, Train Loss: 0.6925, Train Acc: 0.5202, Train F1: 0.3562, Train MCC: 0.0071, Val Loss: 0.6917, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.19s, Total Time: 118.33s
# Epoch 34, Train Loss: 0.6926, Train Acc: 0.5203, Train F1: 0.3563, Train MCC: 0.0069, Val Loss: 0.6918, Val Acc: 0.5300, Val F1: 0.3674, Val MCC: -0.0038, Epoch Time: 3.17s, Total Time: 121.50s
# Epoch 35, Train Loss: 0.6934, Train Acc: 0.5063, Train F1: 0.3632, Train MCC: -0.0738, Val Loss: 0.6921, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 3.13s, Total Time: 124.63s
# Epoch 36, Train Loss: 0.6929, Train Acc: 0.5151, Train F1: 0.3609, Train MCC: -0.0392, Val Loss: 0.6914, Val Acc: 0.5299, Val F1: 0.3673, Val MCC: -0.0097, Epoch Time: 3.10s, Total Time: 127.73s
# Epoch 37, Train Loss: 0.6928, Train Acc: 0.5215, Train F1: 0.3841, Train MCC: 0.0150, Val Loss: 0.6914, Val Acc: 0.5296, Val F1: 0.3698, Val MCC: -0.0050, Epoch Time: 3.09s, Total Time: 130.82s
# Epoch 38, Train Loss: 0.6929, Train Acc: 0.5222, Train F1: 0.4007, Train MCC: 0.0186, Val Loss: 0.6917, Val Acc: 0.5300, Val F1: 0.3673, Val MCC: -0.0071, Epoch Time: 3.17s, Total Time: 133.99s
# Epoch 39, Train Loss: 0.6925, Train Acc: 0.5194, Train F1: 0.3991, Train MCC: 0.0065, Val Loss: 0.6918, Val Acc: 0.5281, Val F1: 0.3845, Val MCC: -0.0039, Epoch Time: 3.22s, Total Time: 137.21s
# Epoch 40, Train Loss: 0.6922, Train Acc: 0.5153, Train F1: 0.3990, Train MCC: -0.0095, Val Loss: 0.6926, Val Acc: 0.4750, Val F1: 0.4069, Val MCC: -0.1225, Epoch Time: 3.12s, Total Time: 140.33s
# Epoch 41, Train Loss: 0.6937, Train Acc: 0.5280, Train F1: 0.4438, Train MCC: 0.0393, Val Loss: 0.6912, Val Acc: 0.5302, Val F1: 0.3676, Val MCC: 0.0121, Epoch Time: 2.86s, Total Time: 143.20s
# Epoch 42, Train Loss: 0.6928, Train Acc: 0.5202, Train F1: 0.3562, Train MCC: 0.0071, Val Loss: 0.6916, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 2.76s, Total Time: 145.95s
# Epoch 43, Train Loss: 0.6922, Train Acc: 0.5171, Train F1: 0.3944, Train MCC: -0.0040, Val Loss: 0.6927, Val Acc: 0.5059, Val F1: 0.4988, Val MCC: -0.0030, Epoch Time: 2.75s, Total Time: 148.70s
# Epoch 44, Train Loss: 0.6920, Train Acc: 0.5167, Train F1: 0.4496, Train MCC: 0.0076, Val Loss: 0.6927, Val Acc: 0.5204, Val F1: 0.5205, Val MCC: 0.0443, Epoch Time: 2.77s, Total Time: 151.47s
# Epoch 45, Train Loss: 0.6921, Train Acc: 0.5425, Train F1: 0.4973, Train MCC: 0.0760, Val Loss: 0.6914, Val Acc: 0.5301, Val F1: 0.3673, Val MCC: 0.0000, Epoch Time: 2.86s, Total Time: 154.33s
# Epoch 46, Train Loss: 0.6927, Train Acc: 0.5180, Train F1: 0.3636, Train MCC: -0.0155, Val Loss: 0.6916, Val Acc: 0.5280, Val F1: 0.3902, Val MCC: -0.0016, Epoch Time: 2.88s, Total Time: 157.22s
# Epoch 47, Train Loss: 0.6915, Train Acc: 0.5326, Train F1: 0.4611, Train MCC: 0.0524, Val Loss: 0.6928, Val Acc: 0.5137, Val F1: 0.5138, Val MCC: 0.0308, Epoch Time: 2.79s, Total Time: 160.01s
# Epoch 48, Train Loss: 0.6909, Train Acc: 0.5441, Train F1: 0.4965, Train MCC: 0.0803, Val Loss: 0.6922, Val Acc: 0.4906, Val F1: 0.3733, Val MCC: -0.1359, Epoch Time: 2.83s, Total Time: 162.84s
# Epoch 49, Train Loss: 0.6908, Train Acc: 0.5377, Train F1: 0.4625, Train MCC: 0.0680, Val Loss: 0.6954, Val Acc: 0.5457, Val F1: 0.5357, Val MCC: 0.1149, Epoch Time: 2.97s, Total Time: 165.81s
# Epoch 50, Train Loss: 0.6908, Train Acc: 0.5358, Train F1: 0.5102, Train MCC: 0.0598, Val Loss: 0.6934, Val Acc: 0.5459, Val F1: 0.5269, Val MCC: 0.1276, Epoch Time: 2.85s, Total Time: 168.66s
# Epoch 51, Train Loss: 0.6904, Train Acc: 0.5437, Train F1: 0.5235, Train MCC: 0.0778, Val Loss: 0.6925, Val Acc: 0.5247, Val F1: 0.5250, Val MCC: 0.0477, Epoch Time: 2.75s, Total Time: 171.41s
# Epoch 52, Train Loss: 0.6898, Train Acc: 0.5539, Train F1: 0.5326, Train MCC: 0.1003, Val Loss: 0.6968, Val Acc: 0.5458, Val F1: 0.5289, Val MCC: 0.1246, Epoch Time: 2.82s, Total Time: 174.23s
# Epoch 53, Train Loss: 0.6894, Train Acc: 0.5576, Train F1: 0.5410, Train MCC: 0.1080, Val Loss: 0.6974, Val Acc: 0.4949, Val F1: 0.4186, Val MCC: 0.0500, Epoch Time: 2.89s, Total Time: 177.12s
# Epoch 54, Train Loss: 0.6886, Train Acc: 0.5562, Train F1: 0.5400, Train MCC: 0.1050, Val Loss: 0.6957, Val Acc: 0.5430, Val F1: 0.5221, Val MCC: 0.1233, Epoch Time: 2.75s, Total Time: 179.87s
# Epoch 55, Train Loss: 0.6870, Train Acc: 0.5535, Train F1: 0.5328, Train MCC: 0.0994, Val Loss: 0.6961, Val Acc: 0.5325, Val F1: 0.4971, Val MCC: 0.1158, Epoch Time: 2.87s, Total Time: 182.74s
# Epoch 56, Train Loss: 0.6847, Train Acc: 0.5666, Train F1: 0.5544, Train MCC: 0.1270, Val Loss: 0.7002, Val Acc: 0.5292, Val F1: 0.4895, Val MCC: 0.1122, Epoch Time: 2.79s, Total Time: 185.53s
# Epoch 57, Train Loss: 0.6853, Train Acc: 0.5654, Train F1: 0.5532, Train MCC: 0.1246, Val Loss: 0.6982, Val Acc: 0.5439, Val F1: 0.5239, Val MCC: 0.1244, Epoch Time: 2.85s, Total Time: 188.38s
# Epoch 58, Train Loss: 0.6842, Train Acc: 0.5575, Train F1: 0.5426, Train MCC: 0.1078, Val Loss: 0.7020, Val Acc: 0.5446, Val F1: 0.5283, Val MCC: 0.1211, Epoch Time: 2.80s, Total Time: 191.18s
# Epoch 59, Train Loss: 0.6836, Train Acc: 0.5576, Train F1: 0.5347, Train MCC: 0.1086, Val Loss: 0.6993, Val Acc: 0.5497, Val F1: 0.5386, Val MCC: 0.1251, Epoch Time: 2.89s, Total Time: 194.06s
# Epoch 60, Train Loss: 0.6823, Train Acc: 0.5611, Train F1: 0.5351, Train MCC: 0.1170, Val Loss: 0.7058, Val Acc: 0.5387, Val F1: 0.5220, Val MCC: 0.1086, Epoch Time: 2.84s, Total Time: 196.90s
# Epoch 61, Train Loss: 0.6811, Train Acc: 0.5665, Train F1: 0.5384, Train MCC: 0.1300, Val Loss: 0.7063, Val Acc: 0.5483, Val F1: 0.5463, Val MCC: 0.1064, Epoch Time: 2.91s, Total Time: 199.82s
# Epoch 62, Train Loss: 0.6831, Train Acc: 0.5687, Train F1: 0.5488, Train MCC: 0.1329, Val Loss: 0.7058, Val Acc: 0.5325, Val F1: 0.5319, Val MCC: 0.0709, Epoch Time: 2.81s, Total Time: 202.63s
# Epoch 63, Train Loss: 0.6826, Train Acc: 0.5692, Train F1: 0.5393, Train MCC: 0.1371, Val Loss: 0.7026, Val Acc: 0.5624, Val F1: 0.5572, Val MCC: 0.1423, Epoch Time: 2.83s, Total Time: 205.47s
# Epoch 64, Train Loss: 0.6806, Train Acc: 0.5660, Train F1: 0.5342, Train MCC: 0.1300, Val Loss: 0.7079, Val Acc: 0.5220, Val F1: 0.4987, Val MCC: 0.0784, Epoch Time: 2.89s, Total Time: 208.35s
# Epoch 65, Train Loss: 0.6803, Train Acc: 0.5682, Train F1: 0.5419, Train MCC: 0.1336, Val Loss: 0.7043, Val Acc: 0.5539, Val F1: 0.5442, Val MCC: 0.1319, Epoch Time: 2.81s, Total Time: 211.17s
# Epoch 66, Train Loss: 0.6785, Train Acc: 0.5674, Train F1: 0.5374, Train MCC: 0.1329, Val Loss: 0.7089, Val Acc: 0.5451, Val F1: 0.5313, Val MCC: 0.1189, Epoch Time: 2.77s, Total Time: 213.94s
# Epoch 67, Train Loss: 0.6773, Train Acc: 0.5767, Train F1: 0.5471, Train MCC: 0.1546, Val Loss: 0.7142, Val Acc: 0.5375, Val F1: 0.5230, Val MCC: 0.1033, Epoch Time: 2.72s, Total Time: 216.66s
# Epoch 68, Train Loss: 0.6766, Train Acc: 0.5773, Train F1: 0.5511, Train MCC: 0.1545, Val Loss: 0.7108, Val Acc: 0.5477, Val F1: 0.5344, Val MCC: 0.1238, Epoch Time: 2.73s, Total Time: 219.39s
# Epoch 69, Train Loss: 0.6765, Train Acc: 0.5800, Train F1: 0.5536, Train MCC: 0.1607, Val Loss: 0.7172, Val Acc: 0.5424, Val F1: 0.5424, Val MCC: 0.0887, Epoch Time: 2.66s, Total Time: 222.05s
# Epoch 70, Train Loss: 0.6754, Train Acc: 0.5795, Train F1: 0.5609, Train MCC: 0.1564, Val Loss: 0.7200, Val Acc: 0.4717, Val F1: 0.4632, Val MCC: -0.0748, Epoch Time: 2.90s, Total Time: 224.95s
# Epoch 71, Train Loss: 0.6734, Train Acc: 0.5858, Train F1: 0.5632, Train MCC: 0.1722, Val Loss: 0.7153, Val Acc: 0.5453, Val F1: 0.5456, Val MCC: 0.0925, Epoch Time: 2.78s, Total Time: 227.73s
# Epoch 72, Train Loss: 0.6742, Train Acc: 0.5805, Train F1: 0.5603, Train MCC: 0.1591, Val Loss: 0.7098, Val Acc: 0.5669, Val F1: 0.5644, Val MCC: 0.1456, Epoch Time: 2.83s, Total Time: 230.56s
# Epoch 73, Train Loss: 0.6717, Train Acc: 0.5834, Train F1: 0.5629, Train MCC: 0.1657, Val Loss: 0.7238, Val Acc: 0.5132, Val F1: 0.5118, Val MCC: 0.0193, Epoch Time: 2.91s, Total Time: 233.48s
# Epoch 74, Train Loss: 0.6728, Train Acc: 0.5839, Train F1: 0.5613, Train MCC: 0.1680, Val Loss: 0.7250, Val Acc: 0.5459, Val F1: 0.5320, Val MCC: 0.1207, Epoch Time: 2.90s, Total Time: 236.37s
# Epoch 75, Train Loss: 0.6707, Train Acc: 0.5875, Train F1: 0.5656, Train MCC: 0.1758, Val Loss: 0.7282, Val Acc: 0.5592, Val F1: 0.5573, Val MCC: 0.1284, Epoch Time: 2.82s, Total Time: 239.20s
# Epoch 76, Train Loss: 0.6682, Train Acc: 0.5870, Train F1: 0.5638, Train MCC: 0.1751, Val Loss: 0.7127, Val Acc: 0.5085, Val F1: 0.5079, Val MCC: 0.0115, Epoch Time: 2.94s, Total Time: 242.14s
# Epoch 77, Train Loss: 0.6674, Train Acc: 0.5909, Train F1: 0.5685, Train MCC: 0.1837, Val Loss: 0.7349, Val Acc: 0.5356, Val F1: 0.5329, Val MCC: 0.0623, Epoch Time: 2.81s, Total Time: 244.95s
# Epoch 78, Train Loss: 0.6681, Train Acc: 0.5885, Train F1: 0.5619, Train MCC: 0.1806, Val Loss: 0.7240, Val Acc: 0.5384, Val F1: 0.5377, Val MCC: 0.0713, Epoch Time: 2.83s, Total Time: 247.78s
# Epoch 79, Train Loss: 0.6687, Train Acc: 0.5850, Train F1: 0.5638, Train MCC: 0.1696, Val Loss: 0.7464, Val Acc: 0.5442, Val F1: 0.5438, Val MCC: 0.0839, Epoch Time: 2.84s, Total Time: 250.62s
# Epoch 80, Train Loss: 0.6672, Train Acc: 0.5936, Train F1: 0.5672, Train MCC: 0.1924, Val Loss: 0.7328, Val Acc: 0.5484, Val F1: 0.5481, Val MCC: 0.0926, Epoch Time: 2.85s, Total Time: 253.47s
# Epoch 81, Train Loss: 0.6656, Train Acc: 0.5992, Train F1: 0.5784, Train MCC: 0.2015, Val Loss: 0.7613, Val Acc: 0.4645, Val F1: 0.4228, Val MCC: -0.1225, Epoch Time: 2.91s, Total Time: 256.38s
# Epoch 82, Train Loss: 0.6627, Train Acc: 0.6030, Train F1: 0.5855, Train MCC: 0.2080, Val Loss: 0.7433, Val Acc: 0.5349, Val F1: 0.5354, Val MCC: 0.0696, Epoch Time: 2.88s, Total Time: 259.26s
# Epoch 83, Train Loss: 0.6596, Train Acc: 0.6023, Train F1: 0.5824, Train MCC: 0.2080, Val Loss: 0.7401, Val Acc: 0.5590, Val F1: 0.5594, Val MCC: 0.1183, Epoch Time: 2.86s, Total Time: 262.12s
# Epoch 84, Train Loss: 0.6586, Train Acc: 0.6058, Train F1: 0.5855, Train MCC: 0.2162, Val Loss: 0.7696, Val Acc: 0.5517, Val F1: 0.5476, Val MCC: 0.0935, Epoch Time: 2.82s, Total Time: 264.94s
# Epoch 85, Train Loss: 0.6568, Train Acc: 0.6107, Train F1: 0.5939, Train MCC: 0.2244, Val Loss: 0.7390, Val Acc: 0.5570, Val F1: 0.5507, Val MCC: 0.1330, Epoch Time: 2.86s, Total Time: 267.80s
# Epoch 86, Train Loss: 0.6575, Train Acc: 0.6107, Train F1: 0.5906, Train MCC: 0.2273, Val Loss: 0.7653, Val Acc: 0.5521, Val F1: 0.5479, Val MCC: 0.1190, Epoch Time: 2.83s, Total Time: 270.63s
# Epoch 87, Train Loss: 0.6554, Train Acc: 0.6126, Train F1: 0.5983, Train MCC: 0.2268, Val Loss: 0.8023, Val Acc: 0.4479, Val F1: 0.4122, Val MCC: -0.0857, Epoch Time: 2.86s, Total Time: 273.49s
# Epoch 88, Train Loss: 0.6608, Train Acc: 0.6040, Train F1: 0.5894, Train MCC: 0.2085, Val Loss: 0.7525, Val Acc: 0.5216, Val F1: 0.5157, Val MCC: 0.0586, Epoch Time: 2.81s, Total Time: 276.30s
# Epoch 89, Train Loss: 0.6625, Train Acc: 0.6012, Train F1: 0.5857, Train MCC: 0.2027, Val Loss: 0.7411, Val Acc: 0.5377, Val F1: 0.5373, Val MCC: 0.0709, Epoch Time: 2.83s, Total Time: 279.12s
# Epoch 90, Train Loss: 0.6563, Train Acc: 0.6086, Train F1: 0.5900, Train MCC: 0.2214, Val Loss: 0.7359, Val Acc: 0.5340, Val F1: 0.5315, Val MCC: 0.0593, Epoch Time: 2.77s, Total Time: 281.90s
# Epoch 91, Train Loss: 0.6536, Train Acc: 0.6093, Train F1: 0.5951, Train MCC: 0.2198, Val Loss: 0.7482, Val Acc: 0.5256, Val F1: 0.5260, Val MCC: 0.0504, Epoch Time: 2.67s, Total Time: 284.57s
# Epoch 92, Train Loss: 0.6505, Train Acc: 0.6161, Train F1: 0.6034, Train MCC: 0.2335, Val Loss: 0.7506, Val Acc: 0.4783, Val F1: 0.4719, Val MCC: -0.0304, Epoch Time: 2.71s, Total Time: 287.28s
# Epoch 93, Train Loss: 0.6537, Train Acc: 0.6143, Train F1: 0.5998, Train MCC: 0.2309, Val Loss: 0.7194, Val Acc: 0.5009, Val F1: 0.4969, Val MCC: 0.0136, Epoch Time: 2.89s, Total Time: 290.17s
# Epoch 94, Train Loss: 0.6536, Train Acc: 0.6169, Train F1: 0.6006, Train MCC: 0.2380, Val Loss: 0.7271, Val Acc: 0.5054, Val F1: 0.5036, Val MCC: 0.0027, Epoch Time: 2.83s, Total Time: 293.00s
# Epoch 95, Train Loss: 0.6508, Train Acc: 0.6175, Train F1: 0.6025, Train MCC: 0.2383, Val Loss: 0.7170, Val Acc: 0.5214, Val F1: 0.5119, Val MCC: 0.0269, Epoch Time: 2.72s, Total Time: 295.72s
# Epoch 96, Train Loss: 0.6480, Train Acc: 0.6220, Train F1: 0.6059, Train MCC: 0.2491, Val Loss: 0.7281, Val Acc: 0.5012, Val F1: 0.4943, Val MCC: -0.0124, Epoch Time: 2.70s, Total Time: 298.42s
# Epoch 97, Train Loss: 0.6455, Train Acc: 0.6234, Train F1: 0.6094, Train MCC: 0.2506, Val Loss: 0.7495, Val Acc: 0.4985, Val F1: 0.4684, Val MCC: -0.0361, Epoch Time: 2.75s, Total Time: 301.17s
# Epoch 98, Train Loss: 0.6469, Train Acc: 0.6251, Train F1: 0.6100, Train MCC: 0.2551, Val Loss: 0.7544, Val Acc: 0.4900, Val F1: 0.4762, Val MCC: -0.0422, Epoch Time: 2.78s, Total Time: 303.96s
# Epoch 99, Train Loss: 0.6469, Train Acc: 0.6227, Train F1: 0.6064, Train MCC: 0.2508, Val Loss: 0.7524, Val Acc: 0.4941, Val F1: 0.4922, Val MCC: -0.0202, Epoch Time: 2.81s, Total Time: 306.76s
# Epoch 100, Train Loss: 0.6572, Train Acc: 0.6123, Train F1: 0.5997, Train MCC: 0.2253, Val Loss: 0.7445, Val Acc: 0.5104, Val F1: 0.5060, Val MCC: 0.0092, Epoch Time: 2.85s, Total Time: 309.62s
# Epoch 101, Train Loss: 0.6532, Train Acc: 0.6177, Train F1: 0.5995, Train MCC: 0.2415, Val Loss: 0.7656, Val Acc: 0.5002, Val F1: 0.4925, Val MCC: -0.0153, Epoch Time: 2.85s, Total Time: 312.46s
# Epoch 102, Train Loss: 0.6546, Train Acc: 0.6081, Train F1: 0.5914, Train MCC: 0.2189, Val Loss: 0.7695, Val Acc: 0.4936, Val F1: 0.4841, Val MCC: 0.0041, Epoch Time: 2.85s, Total Time: 315.31s
# Epoch 103, Train Loss: 0.6510, Train Acc: 0.6117, Train F1: 0.5981, Train MCC: 0.2246, Val Loss: 0.7632, Val Acc: 0.4899, Val F1: 0.4902, Val MCC: -0.0226, Epoch Time: 2.85s, Total Time: 318.17s
# Epoch 104, Train Loss: 0.6523, Train Acc: 0.6101, Train F1: 0.5974, Train MCC: 0.2205, Val Loss: 0.8282, Val Acc: 0.4974, Val F1: 0.4946, Val MCC: 0.0044, Epoch Time: 2.79s, Total Time: 320.96s
# Epoch 105, Train Loss: 0.6451, Train Acc: 0.6236, Train F1: 0.6058, Train MCC: 0.2542, Val Loss: 0.7645, Val Acc: 0.4958, Val F1: 0.4928, Val MCC: -0.0186, Epoch Time: 2.85s, Total Time: 323.81s
# Epoch 106, Train Loss: 0.6445, Train Acc: 0.6166, Train F1: 0.6029, Train MCC: 0.2352, Val Loss: 0.8437, Val Acc: 0.4385, Val F1: 0.4350, Val MCC: -0.1147, Epoch Time: 2.80s, Total Time: 326.60s
# Epoch 107, Train Loss: 0.6472, Train Acc: 0.6223, Train F1: 0.6070, Train MCC: 0.2492, Val Loss: 0.7992, Val Acc: 0.4477, Val F1: 0.4228, Val MCC: -0.0876, Epoch Time: 2.84s, Total Time: 329.44s
# Epoch 108, Train Loss: 0.6406, Train Acc: 0.6292, Train F1: 0.6146, Train MCC: 0.2638, Val Loss: 0.7873, Val Acc: 0.4684, Val F1: 0.4642, Val MCC: -0.0529, Epoch Time: 2.82s, Total Time: 332.26s
# Epoch 109, Train Loss: 0.6418, Train Acc: 0.6260, Train F1: 0.6119, Train MCC: 0.2561, Val Loss: 0.8325, Val Acc: 0.4943, Val F1: 0.4939, Val MCC: -0.0164, Epoch Time: 2.79s, Total Time: 335.05s
# Epoch 110, Train Loss: 0.6404, Train Acc: 0.6301, Train F1: 0.6174, Train MCC: 0.2638, Val Loss: 0.8332, Val Acc: 0.4650, Val F1: 0.4562, Val MCC: -0.0563, Epoch Time: 2.90s, Total Time: 337.95s
# Epoch 111, Train Loss: 0.6393, Train Acc: 0.6307, Train F1: 0.6181, Train MCC: 0.2652, Val Loss: 0.7939, Val Acc: 0.4709, Val F1: 0.4516, Val MCC: -0.0382, Epoch Time: 2.89s, Total Time: 340.83s
# Epoch 112, Train Loss: 0.6391, Train Acc: 0.6292, Train F1: 0.6172, Train MCC: 0.2612, Val Loss: 0.8150, Val Acc: 0.4504, Val F1: 0.4266, Val MCC: -0.0818, Epoch Time: 2.85s, Total Time: 343.68s
# Epoch 113, Train Loss: 0.6385, Train Acc: 0.6310, Train F1: 0.6208, Train MCC: 0.2637, Val Loss: 0.8297, Val Acc: 0.4406, Val F1: 0.4309, Val MCC: -0.1068, Epoch Time: 2.84s, Total Time: 346.52s
# Epoch 114, Train Loss: 0.6370, Train Acc: 0.6326, Train F1: 0.6240, Train MCC: 0.2658, Val Loss: 0.8107, Val Acc: 0.4360, Val F1: 0.3979, Val MCC: -0.1132, Epoch Time: 2.86s, Total Time: 349.38s
# Epoch 115, Train Loss: 0.6440, Train Acc: 0.6205, Train F1: 0.6070, Train MCC: 0.2436, Val Loss: 0.7570, Val Acc: 0.4576, Val F1: 0.3636, Val MCC: -0.2019, Epoch Time: 2.94s, Total Time: 352.32s
# Epoch 116, Train Loss: 0.6461, Train Acc: 0.6163, Train F1: 0.6028, Train MCC: 0.2343, Val Loss: 0.7661, Val Acc: 0.4089, Val F1: 0.3622, Val MCC: -0.2554, Epoch Time: 2.88s, Total Time: 355.19s
# Epoch 117, Train Loss: 0.6434, Train Acc: 0.6220, Train F1: 0.6114, Train MCC: 0.2447, Val Loss: 0.7577, Val Acc: 0.3990, Val F1: 0.3817, Val MCC: -0.2366, Epoch Time: 2.77s, Total Time: 357.97s
# Epoch 118, Train Loss: 0.6373, Train Acc: 0.6309, Train F1: 0.6198, Train MCC: 0.2642, Val Loss: 0.8536, Val Acc: 0.4106, Val F1: 0.4108, Val MCC: -0.1767, Epoch Time: 2.81s, Total Time: 360.78s
# Epoch 119, Train Loss: 0.6373, Train Acc: 0.6341, Train F1: 0.6253, Train MCC: 0.2692, Val Loss: 0.8322, Val Acc: 0.3610, Val F1: 0.3541, Val MCC: -0.2984, Epoch Time: 2.78s, Total Time: 363.56s
# Epoch 120, Train Loss: 0.6413, Train Acc: 0.6302, Train F1: 0.6193, Train MCC: 0.2625, Val Loss: 0.8544, Val Acc: 0.4562, Val F1: 0.4563, Val MCC: -0.0912, Epoch Time: 2.87s, Total Time: 366.43s
# Epoch 121, Train Loss: 0.6385, Train Acc: 0.6244, Train F1: 0.6141, Train MCC: 0.2496, Val Loss: 0.8728, Val Acc: 0.4101, Val F1: 0.4102, Val MCC: -0.1769, Epoch Time: 2.84s, Total Time: 369.26s
# Epoch 122, Train Loss: 0.6417, Train Acc: 0.6201, Train F1: 0.6117, Train MCC: 0.2392, Val Loss: 0.7576, Val Acc: 0.4226, Val F1: 0.3595, Val MCC: -0.2466, Epoch Time: 2.75s, Total Time: 372.01s
# Epoch 123, Train Loss: 0.6390, Train Acc: 0.6294, Train F1: 0.6216, Train MCC: 0.2583, Val Loss: 0.8830, Val Acc: 0.4573, Val F1: 0.4270, Val MCC: -0.0649, Epoch Time: 2.79s, Total Time: 374.80s
# Epoch 124, Train Loss: 0.6348, Train Acc: 0.6341, Train F1: 0.6247, Train MCC: 0.2696, Val Loss: 0.8399, Val Acc: 0.4372, Val F1: 0.4187, Val MCC: -0.1115, Epoch Time: 3.08s, Total Time: 377.88s
# Epoch 125, Train Loss: 0.6329, Train Acc: 0.6387, Train F1: 0.6301, Train MCC: 0.2787, Val Loss: 0.9065, Val Acc: 0.4460, Val F1: 0.4019, Val MCC: -0.0899, Epoch Time: 3.09s, Total Time: 380.97s
# Epoch 126, Train Loss: 0.6341, Train Acc: 0.6346, Train F1: 0.6279, Train MCC: 0.2685, Val Loss: 0.8538, Val Acc: 0.4413, Val F1: 0.4127, Val MCC: -0.1012, Epoch Time: 3.20s, Total Time: 384.17s
# Epoch 127, Train Loss: 0.6347, Train Acc: 0.6374, Train F1: 0.6311, Train MCC: 0.2741, Val Loss: 0.8216, Val Acc: 0.4680, Val F1: 0.4398, Val MCC: -0.0412, Epoch Time: 3.18s, Total Time: 387.35s
# Epoch 128, Train Loss: 0.6340, Train Acc: 0.6338, Train F1: 0.6249, Train MCC: 0.2684, Val Loss: 0.8157, Val Acc: 0.4360, Val F1: 0.3888, Val MCC: -0.1140, Epoch Time: 3.15s, Total Time: 390.50s
# Epoch 129, Train Loss: 0.6348, Train Acc: 0.6363, Train F1: 0.6272, Train MCC: 0.2741, Val Loss: 0.8348, Val Acc: 0.4810, Val F1: 0.4650, Val MCC: -0.0181, Epoch Time: 3.24s, Total Time: 393.74s
# Epoch 130, Train Loss: 0.6364, Train Acc: 0.6330, Train F1: 0.6257, Train MCC: 0.2655, Val Loss: 0.8959, Val Acc: 0.4374, Val F1: 0.3895, Val MCC: -0.1108, Epoch Time: 3.16s, Total Time: 396.90s
# Epoch 131, Train Loss: 0.6329, Train Acc: 0.6385, Train F1: 0.6321, Train MCC: 0.2764, Val Loss: 0.8602, Val Acc: 0.4779, Val F1: 0.4575, Val MCC: -0.0224, Epoch Time: 3.30s, Total Time: 400.20s
# Epoch 132, Train Loss: 0.6363, Train Acc: 0.6308, Train F1: 0.6254, Train MCC: 0.2598, Val Loss: 0.8895, Val Acc: 0.3660, Val F1: 0.3524, Val MCC: -0.2995, Epoch Time: 3.15s, Total Time: 403.35s
# Epoch 133, Train Loss: 0.6340, Train Acc: 0.6363, Train F1: 0.6310, Train MCC: 0.2712, Val Loss: 0.9206, Val Acc: 0.4685, Val F1: 0.4402, Val MCC: -0.0400, Epoch Time: 3.23s, Total Time: 406.58s
# Epoch 134, Train Loss: 0.6278, Train Acc: 0.6412, Train F1: 0.6314, Train MCC: 0.2852, Val Loss: 0.8979, Val Acc: 0.4352, Val F1: 0.3843, Val MCC: -0.1165, Epoch Time: 3.17s, Total Time: 409.75s
# Epoch 135, Train Loss: 0.6267, Train Acc: 0.6434, Train F1: 0.6360, Train MCC: 0.2874, Val Loss: 0.9343, Val Acc: 0.4347, Val F1: 0.3800, Val MCC: -0.1184, Epoch Time: 3.22s, Total Time: 412.97s
# Epoch 136, Train Loss: 0.6276, Train Acc: 0.6416, Train F1: 0.6339, Train MCC: 0.2839, Val Loss: 0.8915, Val Acc: 0.4749, Val F1: 0.4433, Val MCC: -0.0242, Epoch Time: 3.20s, Total Time: 416.17s
# Epoch 137, Train Loss: 0.6321, Train Acc: 0.6354, Train F1: 0.6273, Train MCC: 0.2712, Val Loss: 0.8808, Val Acc: 0.3448, Val F1: 0.3440, Val MCC: -0.3179, Epoch Time: 3.20s, Total Time: 419.37s
# Epoch 138, Train Loss: 0.6296, Train Acc: 0.6429, Train F1: 0.6367, Train MCC: 0.2856, Val Loss: 0.7849, Val Acc: 0.4267, Val F1: 0.4230, Val MCC: -0.1595, Epoch Time: 3.18s, Total Time: 422.55s
# Epoch 139, Train Loss: 0.6305, Train Acc: 0.6415, Train F1: 0.6347, Train MCC: 0.2830, Val Loss: 0.8242, Val Acc: 0.4499, Val F1: 0.4498, Val MCC: -0.0968, Epoch Time: 3.20s, Total Time: 425.75s
# Epoch 140, Train Loss: 0.6283, Train Acc: 0.6440, Train F1: 0.6391, Train MCC: 0.2868, Val Loss: 0.7984, Val Acc: 0.4351, Val F1: 0.4346, Val MCC: -0.1253, Epoch Time: 3.22s, Total Time: 428.97s
# Epoch 141, Train Loss: 0.6263, Train Acc: 0.6442, Train F1: 0.6381, Train MCC: 0.2881, Val Loss: 0.8494, Val Acc: 0.4567, Val F1: 0.4558, Val MCC: -0.0813, Epoch Time: 3.17s, Total Time: 432.15s
# Epoch 142, Train Loss: 0.6231, Train Acc: 0.6482, Train F1: 0.6431, Train MCC: 0.2956, Val Loss: 0.8168, Val Acc: 0.3951, Val F1: 0.3936, Val MCC: -0.2186, Epoch Time: 3.17s, Total Time: 435.32s
# Epoch 143, Train Loss: 0.6254, Train Acc: 0.6429, Train F1: 0.6359, Train MCC: 0.2860, Val Loss: 0.8669, Val Acc: 0.4717, Val F1: 0.4550, Val MCC: -0.0378, Epoch Time: 3.19s, Total Time: 438.51s
# Epoch 144, Train Loss: 0.6291, Train Acc: 0.6444, Train F1: 0.6396, Train MCC: 0.2876, Val Loss: 0.7819, Val Acc: 0.4674, Val F1: 0.4668, Val MCC: -0.0603, Epoch Time: 3.23s, Total Time: 441.75s
# Epoch 145, Train Loss: 0.6280, Train Acc: 0.6396, Train F1: 0.6335, Train MCC: 0.2784, Val Loss: 0.8646, Val Acc: 0.5060, Val F1: 0.4971, Val MCC: 0.0296, Epoch Time: 3.10s, Total Time: 444.85s
# Epoch 146, Train Loss: 0.6260, Train Acc: 0.6476, Train F1: 0.6419, Train MCC: 0.2949, Val Loss: 0.8066, Val Acc: 0.3866, Val F1: 0.3677, Val MCC: -0.2649, Epoch Time: 2.83s, Total Time: 447.68s
# Epoch 147, Train Loss: 0.6303, Train Acc: 0.6432, Train F1: 0.6379, Train MCC: 0.2853, Val Loss: 0.8613, Val Acc: 0.3896, Val F1: 0.3668, Val MCC: -0.2642, Epoch Time: 2.69s, Total Time: 450.37s
# Epoch 148, Train Loss: 0.6318, Train Acc: 0.6446, Train F1: 0.6394, Train MCC: 0.2883, Val Loss: 0.8040, Val Acc: 0.4473, Val F1: 0.4442, Val MCC: -0.0972, Epoch Time: 2.74s, Total Time: 453.11s
# Epoch 149, Train Loss: 0.6249, Train Acc: 0.6458, Train F1: 0.6370, Train MCC: 0.2940, Val Loss: 0.8357, Val Acc: 0.3549, Val F1: 0.3544, Val MCC: -0.2967, Epoch Time: 2.75s, Total Time: 455.86s
# Epoch 150, Train Loss: 0.6234, Train Acc: 0.6440, Train F1: 0.6392, Train MCC: 0.2866, Val Loss: 0.8650, Val Acc: 0.3461, Val F1: 0.3405, Val MCC: -0.3025, Epoch Time: 2.76s, Total Time: 458.62s
# Epoch 151, Train Loss: 0.6237, Train Acc: 0.6509, Train F1: 0.6445, Train MCC: 0.3024, Val Loss: 0.8780, Val Acc: 0.4260, Val F1: 0.3857, Val MCC: -0.1368, Epoch Time: 2.81s, Total Time: 461.43s
# Epoch 152, Train Loss: 0.6278, Train Acc: 0.6416, Train F1: 0.6357, Train MCC: 0.2825, Val Loss: 0.8116, Val Acc: 0.4077, Val F1: 0.4048, Val MCC: -0.1963, Epoch Time: 2.81s, Total Time: 464.24s
# Epoch 153, Train Loss: 0.6247, Train Acc: 0.6495, Train F1: 0.6437, Train MCC: 0.2988, Val Loss: 0.7845, Val Acc: 0.4738, Val F1: 0.4636, Val MCC: -0.0370, Epoch Time: 2.84s, Total Time: 467.08s
# Epoch 154, Train Loss: 0.6278, Train Acc: 0.6466, Train F1: 0.6400, Train MCC: 0.2936, Val Loss: 0.8381, Val Acc: 0.4565, Val F1: 0.4472, Val MCC: -0.0736, Epoch Time: 2.86s, Total Time: 469.94s
# Epoch 155, Train Loss: 0.6295, Train Acc: 0.6469, Train F1: 0.6408, Train MCC: 0.2938, Val Loss: 0.8244, Val Acc: 0.4574, Val F1: 0.4539, Val MCC: -0.0763, Epoch Time: 2.90s, Total Time: 472.84s
# Epoch 156, Train Loss: 0.6260, Train Acc: 0.6473, Train F1: 0.6413, Train MCC: 0.2944, Val Loss: 0.8944, Val Acc: 0.4759, Val F1: 0.4489, Val MCC: -0.0237, Epoch Time: 2.82s, Total Time: 475.66s
# Epoch 157, Train Loss: 0.6225, Train Acc: 0.6503, Train F1: 0.6453, Train MCC: 0.3001, Val Loss: 0.9397, Val Acc: 0.4814, Val F1: 0.4693, Val MCC: -0.0197, Epoch Time: 2.81s, Total Time: 478.47s
# Epoch 158, Train Loss: 0.6207, Train Acc: 0.6527, Train F1: 0.6474, Train MCC: 0.3051, Val Loss: 0.8545, Val Acc: 0.4580, Val F1: 0.4575, Val MCC: -0.0794, Epoch Time: 2.90s, Total Time: 481.37s
# Epoch 159, Train Loss: 0.6256, Train Acc: 0.6435, Train F1: 0.6391, Train MCC: 0.2854, Val Loss: 0.8932, Val Acc: 0.4041, Val F1: 0.4011, Val MCC: -0.2037, Epoch Time: 2.77s, Total Time: 484.14s
# Epoch 160, Train Loss: 0.6278, Train Acc: 0.6474, Train F1: 0.6424, Train MCC: 0.2938, Val Loss: 0.9424, Val Acc: 0.4419, Val F1: 0.3888, Val MCC: -0.1003, Epoch Time: 2.75s, Total Time: 486.89s
# Epoch 161, Train Loss: 0.6259, Train Acc: 0.6446, Train F1: 0.6366, Train MCC: 0.2906, Val Loss: 0.8668, Val Acc: 0.4055, Val F1: 0.4023, Val MCC: -0.2015, Epoch Time: 2.79s, Total Time: 489.68s
# Epoch 162, Train Loss: 0.6337, Train Acc: 0.6402, Train F1: 0.6352, Train MCC: 0.2791, Val Loss: 0.8476, Val Acc: 0.4241, Val F1: 0.4244, Val MCC: -0.1543, Epoch Time: 2.78s, Total Time: 492.46s
# Epoch 163, Train Loss: 0.6395, Train Acc: 0.6369, Train F1: 0.6321, Train MCC: 0.2720, Val Loss: 0.8273, Val Acc: 0.3799, Val F1: 0.3800, Val MCC: -0.2376, Epoch Time: 2.78s, Total Time: 495.24s
# Epoch 164, Train Loss: 0.6366, Train Acc: 0.6315, Train F1: 0.6235, Train MCC: 0.2630, Val Loss: 0.8154, Val Acc: 0.4778, Val F1: 0.4617, Val MCC: -0.0248, Epoch Time: 2.91s, Total Time: 498.15s
# Epoch 165, Train Loss: 0.6275, Train Acc: 0.6377, Train F1: 0.6307, Train MCC: 0.2751, Val Loss: 0.8917, Val Acc: 0.4762, Val F1: 0.4529, Val MCC: -0.0247, Epoch Time: 2.85s, Total Time: 501.01s
# Epoch 166, Train Loss: 0.6287, Train Acc: 0.6477, Train F1: 0.6402, Train MCC: 0.2967, Val Loss: 0.8193, Val Acc: 0.4363, Val F1: 0.4368, Val MCC: -0.1277, Epoch Time: 2.86s, Total Time: 503.87s
# Epoch 167, Train Loss: 0.6266, Train Acc: 0.6444, Train F1: 0.6383, Train MCC: 0.2885, Val Loss: 0.7947, Val Acc: 0.4598, Val F1: 0.4581, Val MCC: -0.0736, Epoch Time: 2.83s, Total Time: 506.70s
# Epoch 168, Train Loss: 0.6206, Train Acc: 0.6515, Train F1: 0.6464, Train MCC: 0.3025, Val Loss: 0.8132, Val Acc: 0.4431, Val F1: 0.4292, Val MCC: -0.1000, Epoch Time: 2.78s, Total Time: 509.48s
# Epoch 169, Train Loss: 0.6184, Train Acc: 0.6553, Train F1: 0.6503, Train MCC: 0.3102, Val Loss: 0.8435, Val Acc: 0.4496, Val F1: 0.4275, Val MCC: -0.0840, Epoch Time: 2.77s, Total Time: 512.25s
# Epoch 170, Train Loss: 0.6182, Train Acc: 0.6552, Train F1: 0.6510, Train MCC: 0.3095, Val Loss: 0.8579, Val Acc: 0.4320, Val F1: 0.3869, Val MCC: -0.1234, Epoch Time: 2.80s, Total Time: 515.05s
# Epoch 171, Train Loss: 0.6215, Train Acc: 0.6526, Train F1: 0.6486, Train MCC: 0.3040, Val Loss: 0.8231, Val Acc: 0.4549, Val F1: 0.4501, Val MCC: -0.0800, Epoch Time: 2.86s, Total Time: 517.91s
# Epoch 172, Train Loss: 0.6189, Train Acc: 0.6546, Train F1: 0.6489, Train MCC: 0.3096, Val Loss: 0.8815, Val Acc: 0.4590, Val F1: 0.4570, Val MCC: -0.0747, Epoch Time: 2.86s, Total Time: 520.77s
# Epoch 173, Train Loss: 0.6182, Train Acc: 0.6563, Train F1: 0.6522, Train MCC: 0.3117, Val Loss: 0.9109, Val Acc: 0.4422, Val F1: 0.4016, Val MCC: -0.0988, Epoch Time: 2.82s, Total Time: 523.60s
# Epoch 174, Train Loss: 0.6175, Train Acc: 0.6564, Train F1: 0.6489, Train MCC: 0.3151, Val Loss: 0.8945, Val Acc: 0.4669, Val F1: 0.4563, Val MCC: -0.0511, Epoch Time: 2.71s, Total Time: 526.31s
# Epoch 175, Train Loss: 0.6168, Train Acc: 0.6549, Train F1: 0.6499, Train MCC: 0.3094, Val Loss: 0.8804, Val Acc: 0.4629, Val F1: 0.4611, Val MCC: -0.0669, Epoch Time: 2.78s, Total Time: 529.09s
# Epoch 176, Train Loss: 0.6161, Train Acc: 0.6556, Train F1: 0.6509, Train MCC: 0.3106, Val Loss: 0.9075, Val Acc: 0.4150, Val F1: 0.3854, Val MCC: -0.1602, Epoch Time: 2.78s, Total Time: 531.87s
# Epoch 177, Train Loss: 0.6192, Train Acc: 0.6530, Train F1: 0.6483, Train MCC: 0.3053, Val Loss: 0.8549, Val Acc: 0.4159, Val F1: 0.3886, Val MCC: -0.1580, Epoch Time: 2.87s, Total Time: 534.73s
# Epoch 178, Train Loss: 0.6185, Train Acc: 0.6535, Train F1: 0.6501, Train MCC: 0.3053, Val Loss: 0.8818, Val Acc: 0.4408, Val F1: 0.4125, Val MCC: -0.1024, Epoch Time: 2.87s, Total Time: 537.60s
# Epoch 179, Train Loss: 0.6204, Train Acc: 0.6538, Train F1: 0.6484, Train MCC: 0.3076, Val Loss: 0.8673, Val Acc: 0.4533, Val F1: 0.4431, Val MCC: -0.0800, Epoch Time: 2.78s, Total Time: 540.38s
# Epoch 180, Train Loss: 0.6200, Train Acc: 0.6510, Train F1: 0.6438, Train MCC: 0.3035, Val Loss: 0.9545, Val Acc: 0.4336, Val F1: 0.4153, Val MCC: -0.1194, Epoch Time: 2.85s, Total Time: 543.23s
# Epoch 181, Train Loss: 0.6187, Train Acc: 0.6553, Train F1: 0.6509, Train MCC: 0.3097, Val Loss: 0.8309, Val Acc: 0.4581, Val F1: 0.4567, Val MCC: -0.0775, Epoch Time: 2.82s, Total Time: 546.05s
# Epoch 182, Train Loss: 0.6202, Train Acc: 0.6516, Train F1: 0.6466, Train MCC: 0.3025, Val Loss: 0.8794, Val Acc: 0.4716, Val F1: 0.4713, Val MCC: -0.0525, Epoch Time: 2.77s, Total Time: 548.81s
# Epoch 183, Train Loss: 0.6192, Train Acc: 0.6544, Train F1: 0.6466, Train MCC: 0.3111, Val Loss: 0.9011, Val Acc: 0.4675, Val F1: 0.4663, Val MCC: -0.0587, Epoch Time: 2.87s, Total Time: 551.68s
# Epoch 184, Train Loss: 0.6157, Train Acc: 0.6549, Train F1: 0.6511, Train MCC: 0.3086, Val Loss: 0.8575, Val Acc: 0.4361, Val F1: 0.4246, Val MCC: -0.1155, Epoch Time: 2.88s, Total Time: 554.56s
# Epoch 185, Train Loss: 0.6164, Train Acc: 0.6534, Train F1: 0.6474, Train MCC: 0.3072, Val Loss: 0.8645, Val Acc: 0.4317, Val F1: 0.4298, Val MCC: -0.1300, Epoch Time: 2.79s, Total Time: 557.35s
# Epoch 186, Train Loss: 0.6166, Train Acc: 0.6586, Train F1: 0.6555, Train MCC: 0.3155, Val Loss: 0.8672, Val Acc: 0.4377, Val F1: 0.3942, Val MCC: -0.1098, Epoch Time: 2.91s, Total Time: 560.26s
# Epoch 187, Train Loss: 0.6160, Train Acc: 0.6575, Train F1: 0.6535, Train MCC: 0.3141, Val Loss: 0.8812, Val Acc: 0.4231, Val F1: 0.3998, Val MCC: -0.1418, Epoch Time: 2.96s, Total Time: 563.22s
# Epoch 188, Train Loss: 0.6148, Train Acc: 0.6583, Train F1: 0.6525, Train MCC: 0.3173, Val Loss: 0.8805, Val Acc: 0.4819, Val F1: 0.4738, Val MCC: -0.0216, Epoch Time: 2.92s, Total Time: 566.13s
# Epoch 189, Train Loss: 0.6179, Train Acc: 0.6548, Train F1: 0.6502, Train MCC: 0.3088, Val Loss: 0.8503, Val Acc: 0.4660, Val F1: 0.4639, Val MCC: -0.0602, Epoch Time: 2.84s, Total Time: 568.98s
# Epoch 190, Train Loss: 0.6162, Train Acc: 0.6574, Train F1: 0.6536, Train MCC: 0.3136, Val Loss: 0.9715, Val Acc: 0.4419, Val F1: 0.4081, Val MCC: -0.0996, Epoch Time: 2.69s, Total Time: 571.67s
# Epoch 191, Train Loss: 0.6162, Train Acc: 0.6546, Train F1: 0.6497, Train MCC: 0.3088, Val Loss: 0.9174, Val Acc: 0.4766, Val F1: 0.4655, Val MCC: -0.0303, Epoch Time: 2.88s, Total Time: 574.55s
# Epoch 192, Train Loss: 0.6141, Train Acc: 0.6588, Train F1: 0.6550, Train MCC: 0.3165, Val Loss: 0.9209, Val Acc: 0.4597, Val F1: 0.4534, Val MCC: -0.0690, Epoch Time: 2.90s, Total Time: 577.46s
# Epoch 193, Train Loss: 0.6160, Train Acc: 0.6577, Train F1: 0.6528, Train MCC: 0.3151, Val Loss: 0.9873, Val Acc: 0.4748, Val F1: 0.4440, Val MCC: -0.0248, Epoch Time: 2.80s, Total Time: 580.26s
# Epoch 194, Train Loss: 0.6139, Train Acc: 0.6590, Train F1: 0.6558, Train MCC: 0.3164, Val Loss: 0.8652, Val Acc: 0.4352, Val F1: 0.3840, Val MCC: -0.1166, Epoch Time: 2.83s, Total Time: 583.08s
# Epoch 195, Train Loss: 0.6186, Train Acc: 0.6585, Train F1: 0.6559, Train MCC: 0.3152, Val Loss: 0.9539, Val Acc: 0.4291, Val F1: 0.3577, Val MCC: -0.1375, Epoch Time: 2.92s, Total Time: 586.01s
# Epoch 196, Train Loss: 0.6192, Train Acc: 0.6561, Train F1: 0.6513, Train MCC: 0.3119, Val Loss: 1.0181, Val Acc: 0.4443, Val F1: 0.3920, Val MCC: -0.0943, Epoch Time: 2.76s, Total Time: 588.77s
# Epoch 197, Train Loss: 0.6228, Train Acc: 0.6486, Train F1: 0.6436, Train MCC: 0.2963, Val Loss: 0.8059, Val Acc: 0.4089, Val F1: 0.4006, Val MCC: -0.2031, Epoch Time: 2.76s, Total Time: 591.52s
# Epoch 198, Train Loss: 0.6185, Train Acc: 0.6565, Train F1: 0.6520, Train MCC: 0.3124, Val Loss: 0.8543, Val Acc: 0.4900, Val F1: 0.4870, Val MCC: -0.0304, Epoch Time: 2.79s, Total Time: 594.31s
# Epoch 199, Train Loss: 0.6160, Train Acc: 0.6548, Train F1: 0.6501, Train MCC: 0.3091, Val Loss: 0.8907, Val Acc: 0.4870, Val F1: 0.4666, Val MCC: -0.0021, Epoch Time: 2.84s, Total Time: 597.15s
# Epoch 200, Train Loss: 0.6153, Train Acc: 0.6607, Train F1: 0.6561, Train MCC: 0.3213, Val Loss: 0.8863, Val Acc: 0.4380, Val F1: 0.4385, Val MCC: -0.1255, Epoch Time: 2.82s, Total Time: 599.97s
# Epoch 201, Train Loss: 0.6192, Train Acc: 0.6529, Train F1: 0.6491, Train MCC: 0.3045, Val Loss: 0.9453, Val Acc: 0.5031, Val F1: 0.5030, Val MCC: 0.0102, Epoch Time: 2.88s, Total Time: 602.85s
# Epoch 202, Train Loss: 0.6141, Train Acc: 0.6609, Train F1: 0.6569, Train MCC: 0.3211, Val Loss: 0.9178, Val Acc: 0.4813, Val F1: 0.4531, Val MCC: -0.0110, Epoch Time: 2.69s, Total Time: 605.53s
# Epoch 203, Train Loss: 0.6151, Train Acc: 0.6593, Train F1: 0.6551, Train MCC: 0.3180, Val Loss: 0.9823, Val Acc: 0.4340, Val F1: 0.3781, Val MCC: -0.1203, Epoch Time: 2.80s, Total Time: 608.33s
# Epoch 204, Train Loss: 0.6161, Train Acc: 0.6576, Train F1: 0.6543, Train MCC: 0.3137, Val Loss: 0.8898, Val Acc: 0.4831, Val F1: 0.4729, Val MCC: -0.0174, Epoch Time: 2.82s, Total Time: 611.15s
# Epoch 205, Train Loss: 0.6115, Train Acc: 0.6608, Train F1: 0.6577, Train MCC: 0.3201, Val Loss: 0.9187, Val Acc: 0.4567, Val F1: 0.4508, Val MCC: -0.0756, Epoch Time: 2.77s, Total Time: 613.93s
# Epoch 206, Train Loss: 0.6150, Train Acc: 0.6577, Train F1: 0.6547, Train MCC: 0.3138, Val Loss: 0.9292, Val Acc: 0.4192, Val F1: 0.4035, Val MCC: -0.1503, Epoch Time: 2.83s, Total Time: 616.76s
# Epoch 207, Train Loss: 0.6145, Train Acc: 0.6568, Train F1: 0.6524, Train MCC: 0.3129, Val Loss: 0.9080, Val Acc: 0.4042, Val F1: 0.3934, Val MCC: -0.1823, Epoch Time: 2.94s, Total Time: 619.70s
# Epoch 208, Train Loss: 0.6229, Train Acc: 0.6492, Train F1: 0.6459, Train MCC: 0.2964, Val Loss: 0.9060, Val Acc: 0.4249, Val F1: 0.3432, Val MCC: -0.1535, Epoch Time: 2.88s, Total Time: 622.58s
# Epoch 209, Train Loss: 0.6254, Train Acc: 0.6445, Train F1: 0.6392, Train MCC: 0.2881, Val Loss: 0.9168, Val Acc: 0.4225, Val F1: 0.3539, Val MCC: -0.1537, Epoch Time: 2.85s, Total Time: 625.44s
# Epoch 210, Train Loss: 0.6324, Train Acc: 0.6345, Train F1: 0.6291, Train MCC: 0.2676, Val Loss: 0.8402, Val Acc: 0.4588, Val F1: 0.4348, Val MCC: -0.0631, Epoch Time: 2.87s, Total Time: 628.30s
# Epoch 211, Train Loss: 0.6299, Train Acc: 0.6404, Train F1: 0.6385, Train MCC: 0.2782, Val Loss: 0.8574, Val Acc: 0.5048, Val F1: 0.4959, Val MCC: 0.0270, Epoch Time: 2.83s, Total Time: 631.14s
# Epoch 212, Train Loss: 0.6165, Train Acc: 0.6562, Train F1: 0.6527, Train MCC: 0.3109, Val Loss: 0.8910, Val Acc: 0.4889, Val F1: 0.4674, Val MCC: 0.0025, Epoch Time: 2.90s, Total Time: 634.04s
# Epoch 213, Train Loss: 0.6150, Train Acc: 0.6588, Train F1: 0.6562, Train MCC: 0.3156, Val Loss: 0.8800, Val Acc: 0.4793, Val F1: 0.4570, Val MCC: -0.0183, Epoch Time: 2.83s, Total Time: 636.87s
# Epoch 214, Train Loss: 0.6129, Train Acc: 0.6623, Train F1: 0.6595, Train MCC: 0.3231, Val Loss: 0.9038, Val Acc: 0.4976, Val F1: 0.4809, Val MCC: 0.0186, Epoch Time: 2.85s, Total Time: 639.71s
# Epoch 215, Train Loss: 0.6112, Train Acc: 0.6612, Train F1: 0.6557, Train MCC: 0.3231, Val Loss: 0.8509, Val Acc: 0.4818, Val F1: 0.4523, Val MCC: -0.0091, Epoch Time: 2.91s, Total Time: 642.63s
# Epoch 216, Train Loss: 0.6099, Train Acc: 0.6632, Train F1: 0.6605, Train MCC: 0.3248, Val Loss: 0.8651, Val Acc: 0.4753, Val F1: 0.4449, Val MCC: -0.0236, Epoch Time: 2.92s, Total Time: 645.54s
# Epoch 217, Train Loss: 0.6093, Train Acc: 0.6647, Train F1: 0.6617, Train MCC: 0.3280, Val Loss: 0.8963, Val Acc: 0.4767, Val F1: 0.4451, Val MCC: -0.0200, Epoch Time: 2.87s, Total Time: 648.41s
# Epoch 218, Train Loss: 0.6093, Train Acc: 0.6639, Train F1: 0.6610, Train MCC: 0.3264, Val Loss: 0.8503, Val Acc: 0.4771, Val F1: 0.4459, Val MCC: -0.0193, Epoch Time: 2.88s, Total Time: 651.29s
# Epoch 219, Train Loss: 0.6093, Train Acc: 0.6646, Train F1: 0.6621, Train MCC: 0.3274, Val Loss: 0.8884, Val Acc: 0.4861, Val F1: 0.4507, Val MCC: 0.0038, Epoch Time: 2.85s, Total Time: 654.14s
# Epoch 220, Train Loss: 0.6090, Train Acc: 0.6640, Train F1: 0.6610, Train MCC: 0.3266, Val Loss: 0.8414, Val Acc: 0.4402, Val F1: 0.3744, Val MCC: -0.1063, Epoch Time: 2.77s, Total Time: 656.91s
# Epoch 221, Train Loss: 0.6092, Train Acc: 0.6626, Train F1: 0.6591, Train MCC: 0.3241, Val Loss: 0.8508, Val Acc: 0.4749, Val F1: 0.3440, Val MCC: 0.0103, Epoch Time: 2.76s, Total Time: 659.67s
# Epoch 222, Train Loss: 0.6129, Train Acc: 0.6613, Train F1: 0.6582, Train MCC: 0.3211, Val Loss: 0.8915, Val Acc: 0.4768, Val F1: 0.4394, Val MCC: -0.0176, Epoch Time: 2.82s, Total Time: 662.49s
# Epoch 223, Train Loss: 0.6151, Train Acc: 0.6537, Train F1: 0.6505, Train MCC: 0.3057, Val Loss: 0.9088, Val Acc: 0.4726, Val F1: 0.4444, Val MCC: -0.0306, Epoch Time: 2.84s, Total Time: 665.32s
# Epoch 224, Train Loss: 0.6130, Train Acc: 0.6582, Train F1: 0.6509, Train MCC: 0.3187, Val Loss: 0.8779, Val Acc: 0.4278, Val F1: 0.3507, Val MCC: -0.1434, Epoch Time: 2.90s, Total Time: 668.22s
# Epoch 225, Train Loss: 0.6104, Train Acc: 0.6618, Train F1: 0.6589, Train MCC: 0.3221, Val Loss: 0.8663, Val Acc: 0.4275, Val F1: 0.3468, Val MCC: -0.1458, Epoch Time: 2.86s, Total Time: 671.08s
# Epoch 226, Train Loss: 0.6103, Train Acc: 0.6633, Train F1: 0.6603, Train MCC: 0.3251, Val Loss: 0.9111, Val Acc: 0.4697, Val F1: 0.4431, Val MCC: -0.0380, Epoch Time: 2.86s, Total Time: 673.94s
# Epoch 227, Train Loss: 0.6118, Train Acc: 0.6620, Train F1: 0.6584, Train MCC: 0.3229, Val Loss: 1.0206, Val Acc: 0.4280, Val F1: 0.3505, Val MCC: -0.1429, Epoch Time: 2.87s, Total Time: 676.80s
# Epoch 228, Train Loss: 0.6134, Train Acc: 0.6559, Train F1: 0.6512, Train MCC: 0.3114, Val Loss: 0.9016, Val Acc: 0.4722, Val F1: 0.4479, Val MCC: -0.0333, Epoch Time: 3.07s, Total Time: 679.87s
# Epoch 229, Train Loss: 0.6143, Train Acc: 0.6578, Train F1: 0.6540, Train MCC: 0.3144, Val Loss: 0.9108, Val Acc: 0.4241, Val F1: 0.3480, Val MCC: -0.1529, Epoch Time: 3.01s, Total Time: 682.88s
# Epoch 230, Train Loss: 0.6138, Train Acc: 0.6601, Train F1: 0.6574, Train MCC: 0.3185, Val Loss: 0.8961, Val Acc: 0.4773, Val F1: 0.4465, Val MCC: -0.0190, Epoch Time: 3.25s, Total Time: 686.13s
# Epoch 231, Train Loss: 0.6125, Train Acc: 0.6594, Train F1: 0.6547, Train MCC: 0.3187, Val Loss: 0.9136, Val Acc: 0.4835, Val F1: 0.4399, Val MCC: 0.0012, Epoch Time: 3.22s, Total Time: 689.35s
# Epoch 232, Train Loss: 0.6148, Train Acc: 0.6569, Train F1: 0.6532, Train MCC: 0.3125, Val Loss: 0.8514, Val Acc: 0.4130, Val F1: 0.3763, Val MCC: -0.1662, Epoch Time: 3.21s, Total Time: 692.56s
# Epoch 233, Train Loss: 0.6179, Train Acc: 0.6523, Train F1: 0.6490, Train MCC: 0.3029, Val Loss: 0.9814, Val Acc: 0.4123, Val F1: 0.4093, Val MCC: -0.1683, Epoch Time: 3.20s, Total Time: 695.77s
# Epoch 234, Train Loss: 0.6176, Train Acc: 0.6537, Train F1: 0.6496, Train MCC: 0.3064, Val Loss: 0.9731, Val Acc: 0.4733, Val F1: 0.4381, Val MCC: -0.0266, Epoch Time: 3.09s, Total Time: 698.85s
# Epoch 235, Train Loss: 0.6130, Train Acc: 0.6575, Train F1: 0.6539, Train MCC: 0.3137, Val Loss: 0.9751, Val Acc: 0.4675, Val F1: 0.4312, Val MCC: -0.0400, Epoch Time: 3.04s, Total Time: 701.90s
# Epoch 236, Train Loss: 0.6133, Train Acc: 0.6606, Train F1: 0.6568, Train MCC: 0.3201, Val Loss: 0.9333, Val Acc: 0.4578, Val F1: 0.4464, Val MCC: -0.0700, Epoch Time: 3.19s, Total Time: 705.09s
# Epoch 237, Train Loss: 0.6118, Train Acc: 0.6595, Train F1: 0.6564, Train MCC: 0.3174, Val Loss: 0.9249, Val Acc: 0.4241, Val F1: 0.3620, Val MCC: -0.1470, Epoch Time: 3.14s, Total Time: 708.22s
# Epoch 238, Train Loss: 0.6099, Train Acc: 0.6642, Train F1: 0.6613, Train MCC: 0.3269, Val Loss: 0.8885, Val Acc: 0.4684, Val F1: 0.4322, Val MCC: -0.0377, Epoch Time: 3.18s, Total Time: 711.40s
# Epoch 239, Train Loss: 0.6102, Train Acc: 0.6640, Train F1: 0.6615, Train MCC: 0.3263, Val Loss: 0.9202, Val Acc: 0.4364, Val F1: 0.3679, Val MCC: -0.1170, Epoch Time: 3.19s, Total Time: 714.59s
# Epoch 240, Train Loss: 0.6107, Train Acc: 0.6612, Train F1: 0.6581, Train MCC: 0.3208, Val Loss: 0.8936, Val Acc: 0.4773, Val F1: 0.4441, Val MCC: -0.0178, Epoch Time: 3.22s, Total Time: 717.80s
# Epoch 241, Train Loss: 0.6114, Train Acc: 0.6631, Train F1: 0.6594, Train MCC: 0.3254, Val Loss: 0.8737, Val Acc: 0.4691, Val F1: 0.4345, Val MCC: -0.0365, Epoch Time: 3.17s, Total Time: 720.97s
# Epoch 242, Train Loss: 0.6090, Train Acc: 0.6628, Train F1: 0.6607, Train MCC: 0.3237, Val Loss: 0.8677, Val Acc: 0.4527, Val F1: 0.4113, Val MCC: -0.0739, Epoch Time: 3.23s, Total Time: 724.21s
# Epoch 243, Train Loss: 0.6078, Train Acc: 0.6655, Train F1: 0.6627, Train MCC: 0.3296, Val Loss: 0.8680, Val Acc: 0.4779, Val F1: 0.4453, Val MCC: -0.0167, Epoch Time: 3.23s, Total Time: 727.44s
# Epoch 244, Train Loss: 0.6084, Train Acc: 0.6644, Train F1: 0.6614, Train MCC: 0.3274, Val Loss: 0.8954, Val Acc: 0.4795, Val F1: 0.4481, Val MCC: -0.0135, Epoch Time: 3.14s, Total Time: 730.58s
# Epoch 245, Train Loss: 0.6079, Train Acc: 0.6639, Train F1: 0.6615, Train MCC: 0.3260, Val Loss: 0.9384, Val Acc: 0.4727, Val F1: 0.4336, Val MCC: -0.0267, Epoch Time: 3.20s, Total Time: 733.78s
# Epoch 246, Train Loss: 0.6084, Train Acc: 0.6637, Train F1: 0.6592, Train MCC: 0.3274, Val Loss: 0.9225, Val Acc: 0.4134, Val F1: 0.3665, Val MCC: -0.1681, Epoch Time: 3.24s, Total Time: 737.01s
# Epoch 247, Train Loss: 0.6094, Train Acc: 0.6629, Train F1: 0.6601, Train MCC: 0.3242, Val Loss: 0.9193, Val Acc: 0.4163, Val F1: 0.3705, Val MCC: -0.1609, Epoch Time: 3.11s, Total Time: 740.12s
# ...
# Epoch 520, Train Loss: 0.6041, Train Acc: 0.6667, Train F1: 0.6650, Train MCC: 0.3313, Val Loss: 0.8303, Val Acc: 0.3940, Val F1: 0.3833, Val MCC: -0.2036, Epoch Time: 2.84s, Total Time: 1531.45s
# Epoch 521, Train Loss: 0.6028, Train Acc: 0.6679, Train F1: 0.6666, Train MCC: 0.3337, Val Loss: 0.8145, Val Acc: 0.3879, Val F1: 0.3749, Val MCC: -0.2165, Epoch Time: 2.91s, Total Time: 1534.36s
# Epoch 522, Train Loss: 0.6023, Train Acc: 0.6683, Train F1: 0.6668, Train MCC: 0.3345, Val Loss: 0.8255, Val Acc: 0.3891, Val F1: 0.3774, Val MCC: -0.2140, Epoch Time: 2.94s, Total Time: 1537.30s
# Epoch 523, Train Loss: 0.6018, Train Acc: 0.6683, Train F1: 0.6670, Train MCC: 0.3345, Val Loss: 0.8163, Val Acc: 0.3890, Val F1: 0.3758, Val MCC: -0.2142, Epoch Time: 2.86s, Total Time: 1540.16s
# Epoch 524, Train Loss: 0.6025, Train Acc: 0.6682, Train F1: 0.6662, Train MCC: 0.3345, Val Loss: 0.8084, Val Acc: 0.3949, Val F1: 0.3813, Val MCC: -0.2017, Epoch Time: 2.90s, Total Time: 1543.06s
# Epoch 525, Train Loss: 0.6031, Train Acc: 0.6682, Train F1: 0.6666, Train MCC: 0.3344, Val Loss: 0.8045, Val Acc: 0.4393, Val F1: 0.4387, Val MCC: -0.1165, Epoch Time: 2.91s, Total Time: 1545.98s
# Epoch 526, Train Loss: 0.6026, Train Acc: 0.6674, Train F1: 0.6656, Train MCC: 0.3327, Val Loss: 0.8621, Val Acc: 0.4303, Val F1: 0.4281, Val MCC: -0.1327, Epoch Time: 2.86s, Total Time: 1548.84s
# Epoch 527, Train Loss: 0.6018, Train Acc: 0.6683, Train F1: 0.6666, Train MCC: 0.3346, Val Loss: 0.7956, Val Acc: 0.4082, Val F1: 0.4010, Val MCC: -0.1748, Epoch Time: 2.90s, Total Time: 1551.74s
# Epoch 528, Train Loss: 0.6016, Train Acc: 0.6690, Train F1: 0.6674, Train MCC: 0.3360, Val Loss: 0.7920, Val Acc: 0.4170, Val F1: 0.4130, Val MCC: -0.1583, Epoch Time: 2.86s, Total Time: 1554.61s
# Epoch 529, Train Loss: 0.6029, Train Acc: 0.6685, Train F1: 0.6666, Train MCC: 0.3350, Val Loss: 0.7858, Val Acc: 0.4410, Val F1: 0.4406, Val MCC: -0.1137, Epoch Time: 2.87s, Total Time: 1557.48s
# Epoch 530, Train Loss: 0.6061, Train Acc: 0.6641, Train F1: 0.6628, Train MCC: 0.3261, Val Loss: 0.7828, Val Acc: 0.4461, Val F1: 0.4454, Val MCC: -0.1029, Epoch Time: 2.88s, Total Time: 1560.36s
# Epoch 531, Train Loss: 0.6056, Train Acc: 0.6668, Train F1: 0.6648, Train MCC: 0.3318, Val Loss: 0.7783, Val Acc: 0.4395, Val F1: 0.4181, Val MCC: -0.1060, Epoch Time: 2.89s, Total Time: 1563.26s
# Epoch 532, Train Loss: 0.6083, Train Acc: 0.6658, Train F1: 0.6646, Train MCC: 0.3294, Val Loss: 0.7532, Val Acc: 0.4323, Val F1: 0.4300, Val MCC: -0.1285, Epoch Time: 2.87s, Total Time: 1566.12s
# Epoch 533, Train Loss: 0.6064, Train Acc: 0.6647, Train F1: 0.6634, Train MCC: 0.3271, Val Loss: 0.8017, Val Acc: 0.4357, Val F1: 0.4360, Val MCC: -0.1271, Epoch Time: 2.85s, Total Time: 1568.98s
# Epoch 534, Train Loss: 0.6095, Train Acc: 0.6637, Train F1: 0.6618, Train MCC: 0.3254, Val Loss: 0.8660, Val Acc: 0.4179, Val F1: 0.4130, Val MCC: -0.1557, Epoch Time: 2.88s, Total Time: 1571.86s
# Epoch 535, Train Loss: 0.6081, Train Acc: 0.6646, Train F1: 0.6625, Train MCC: 0.3273, Val Loss: 0.7503, Val Acc: 0.4328, Val F1: 0.4042, Val MCC: -0.1204, Epoch Time: 2.90s, Total Time: 1574.76s
# Epoch 536, Train Loss: 0.6059, Train Acc: 0.6651, Train F1: 0.6638, Train MCC: 0.3281, Val Loss: 0.8362, Val Acc: 0.4400, Val F1: 0.4383, Val MCC: -0.1133, Epoch Time: 3.13s, Total Time: 1577.89s
# Epoch 537, Train Loss: 0.6035, Train Acc: 0.6659, Train F1: 0.6643, Train MCC: 0.3296, Val Loss: 0.8634, Val Acc: 0.3980, Val F1: 0.3836, Val MCC: -0.1952, Epoch Time: 3.11s, Total Time: 1580.99s
# Epoch 538, Train Loss: 0.6024, Train Acc: 0.6679, Train F1: 0.6660, Train MCC: 0.3338, Val Loss: 0.8331, Val Acc: 0.3993, Val F1: 0.3849, Val MCC: -0.1926, Epoch Time: 3.13s, Total Time: 1584.13s
# Epoch 539, Train Loss: 0.6020, Train Acc: 0.6678, Train F1: 0.6663, Train MCC: 0.3335, Val Loss: 0.8337, Val Acc: 0.3987, Val F1: 0.3854, Val MCC: -0.1937, Epoch Time: 3.21s, Total Time: 1587.33s
# Epoch 540, Train Loss: 0.6017, Train Acc: 0.6691, Train F1: 0.6673, Train MCC: 0.3362, Val Loss: 0.8179, Val Acc: 0.4042, Val F1: 0.3952, Val MCC: -0.1827, Epoch Time: 3.16s, Total Time: 1590.49s
# Epoch 541, Train Loss: 0.6013, Train Acc: 0.6681, Train F1: 0.6667, Train MCC: 0.3341, Val Loss: 0.7947, Val Acc: 0.4395, Val F1: 0.4384, Val MCC: -0.1153, Epoch Time: 3.16s, Total Time: 1593.65s
# Epoch 542, Train Loss: 0.6013, Train Acc: 0.6691, Train F1: 0.6678, Train MCC: 0.3362, Val Loss: 0.7985, Val Acc: 0.4235, Val F1: 0.4216, Val MCC: -0.1467, Epoch Time: 3.12s, Total Time: 1596.77s
# Epoch 543, Train Loss: 0.6043, Train Acc: 0.6671, Train F1: 0.6649, Train MCC: 0.3324, Val Loss: 0.7863, Val Acc: 0.4461, Val F1: 0.4453, Val MCC: -0.1026, Epoch Time: 3.18s, Total Time: 1599.95s
# Epoch 544, Train Loss: 0.6038, Train Acc: 0.6675, Train F1: 0.6654, Train MCC: 0.3331, Val Loss: 0.8043, Val Acc: 0.4273, Val F1: 0.4206, Val MCC: -0.1356, Epoch Time: 3.09s, Total Time: 1603.04s
# Epoch 545, Train Loss: 0.6031, Train Acc: 0.6679, Train F1: 0.6663, Train MCC: 0.3338, Val Loss: 0.7734, Val Acc: 0.4466, Val F1: 0.4454, Val MCC: -0.1011, Epoch Time: 3.16s, Total Time: 1606.19s
# Epoch 546, Train Loss: 0.6027, Train Acc: 0.6678, Train F1: 0.6660, Train MCC: 0.3337, Val Loss: 0.7715, Val Acc: 0.4526, Val F1: 0.4513, Val MCC: -0.0887, Epoch Time: 3.21s, Total Time: 1609.41s
# Epoch 547, Train Loss: 0.6024, Train Acc: 0.6685, Train F1: 0.6670, Train MCC: 0.3350, Val Loss: 0.8384, Val Acc: 0.3962, Val F1: 0.3824, Val MCC: -0.1992, Epoch Time: 3.20s, Total Time: 1612.61s
# Epoch 548, Train Loss: 0.6033, Train Acc: 0.6677, Train F1: 0.6652, Train MCC: 0.3337, Val Loss: 0.7798, Val Acc: 0.4623, Val F1: 0.4598, Val MCC: -0.0674, Epoch Time: 3.28s, Total Time: 1615.88s
# Epoch 549, Train Loss: 0.6031, Train Acc: 0.6669, Train F1: 0.6654, Train MCC: 0.3318, Val Loss: 0.8081, Val Acc: 0.4418, Val F1: 0.4422, Val MCC: -0.1148, Epoch Time: 3.18s, Total Time: 1619.06s
# Epoch 550, Train Loss: 0.6021, Train Acc: 0.6689, Train F1: 0.6673, Train MCC: 0.3356, Val Loss: 0.7899, Val Acc: 0.4183, Val F1: 0.4098, Val MCC: -0.1536, Epoch Time: 3.18s, Total Time: 1622.24s
# Epoch 551, Train Loss: 0.6023, Train Acc: 0.6679, Train F1: 0.6658, Train MCC: 0.3339, Val Loss: 0.7803, Val Acc: 0.4440, Val F1: 0.4355, Val MCC: -0.1002, Epoch Time: 3.11s, Total Time: 1625.36s
# Epoch 552, Train Loss: 0.6024, Train Acc: 0.6688, Train F1: 0.6670, Train MCC: 0.3356, Val Loss: 0.8189, Val Acc: 0.4116, Val F1: 0.3971, Val MCC: -0.1666, Epoch Time: 3.04s, Total Time: 1628.40s
# Epoch 553, Train Loss: 0.6021, Train Acc: 0.6688, Train F1: 0.6669, Train MCC: 0.3356, Val Loss: 0.8189, Val Acc: 0.4265, Val F1: 0.4103, Val MCC: -0.1347, Epoch Time: 3.10s, Total Time: 1631.50s
# Epoch 554, Train Loss: 0.6016, Train Acc: 0.6692, Train F1: 0.6668, Train MCC: 0.3368, Val Loss: 0.7705, Val Acc: 0.4470, Val F1: 0.4422, Val MCC: -0.0963, Epoch Time: 3.16s, Total Time: 1634.66s
# Epoch 555, Train Loss: 0.6022, Train Acc: 0.6683, Train F1: 0.6662, Train MCC: 0.3348, Val Loss: 0.7977, Val Acc: 0.4381, Val F1: 0.4342, Val MCC: -0.1152, Epoch Time: 3.18s, Total Time: 1637.83s
# Epoch 556, Train Loss: 0.6028, Train Acc: 0.6672, Train F1: 0.6658, Train MCC: 0.3322, Val Loss: 0.8041, Val Acc: 0.4024, Val F1: 0.3914, Val MCC: -0.1862, Epoch Time: 3.20s, Total Time: 1641.03s
# Epoch 557, Train Loss: 0.6017, Train Acc: 0.6693, Train F1: 0.6677, Train MCC: 0.3366, Val Loss: 0.8027, Val Acc: 0.4024, Val F1: 0.3928, Val MCC: -0.1862, Epoch Time: 3.09s, Total Time: 1644.12s
# Epoch 558, Train Loss: 0.6019, Train Acc: 0.6692, Train F1: 0.6677, Train MCC: 0.3364, Val Loss: 0.7865, Val Acc: 0.4128, Val F1: 0.3906, Val MCC: -0.1642, Epoch Time: 2.89s, Total Time: 1647.01s
# Epoch 559, Train Loss: 0.6045, Train Acc: 0.6685, Train F1: 0.6665, Train MCC: 0.3351, Val Loss: 0.7883, Val Acc: 0.4467, Val F1: 0.4420, Val MCC: -0.0969, Epoch Time: 2.81s, Total Time: 1649.82s
# Epoch 560, Train Loss: 0.6119, Train Acc: 0.6624, Train F1: 0.6606, Train MCC: 0.3226, Val Loss: 0.8250, Val Acc: 0.4338, Val F1: 0.4306, Val MCC: -0.1246, Epoch Time: 2.79s, Total Time: 1652.60s
# Epoch 561, Train Loss: 0.6166, Train Acc: 0.6550, Train F1: 0.6533, Train MCC: 0.3077, Val Loss: 0.8187, Val Acc: 0.4499, Val F1: 0.4406, Val MCC: -0.0874, Epoch Time: 2.81s, Total Time: 1655.41s
# Epoch 562, Train Loss: 0.6117, Train Acc: 0.6615, Train F1: 0.6579, Train MCC: 0.3219, Val Loss: 0.7968, Val Acc: 0.4402, Val F1: 0.4388, Val MCC: -0.1137, Epoch Time: 2.90s, Total Time: 1658.31s
# Epoch 563, Train Loss: 0.6073, Train Acc: 0.6658, Train F1: 0.6648, Train MCC: 0.3294, Val Loss: 0.7942, Val Acc: 0.4620, Val F1: 0.4624, Val MCC: -0.0777, Epoch Time: 2.86s, Total Time: 1661.16s
# Epoch 564, Train Loss: 0.6066, Train Acc: 0.6668, Train F1: 0.6642, Train MCC: 0.3320, Val Loss: 0.8414, Val Acc: 0.4039, Val F1: 0.3926, Val MCC: -0.1831, Epoch Time: 2.84s, Total Time: 1664.01s
# Epoch 565, Train Loss: 0.6057, Train Acc: 0.6645, Train F1: 0.6621, Train MCC: 0.3273, Val Loss: 0.8171, Val Acc: 0.4238, Val F1: 0.3953, Val MCC: -0.1404, Epoch Time: 2.88s, Total Time: 1666.88s
# Epoch 566, Train Loss: 0.6056, Train Acc: 0.6679, Train F1: 0.6658, Train MCC: 0.3341, Val Loss: 0.8828, Val Acc: 0.4463, Val F1: 0.4455, Val MCC: -0.1022, Epoch Time: 2.80s, Total Time: 1669.68s
# Epoch 567, Train Loss: 0.6043, Train Acc: 0.6655, Train F1: 0.6643, Train MCC: 0.3289, Val Loss: 0.7676, Val Acc: 0.4596, Val F1: 0.4600, Val MCC: -0.0795, Epoch Time: 2.70s, Total Time: 1672.38s
# Epoch 568, Train Loss: 0.6031, Train Acc: 0.6680, Train F1: 0.6662, Train MCC: 0.3341, Val Loss: 0.8032, Val Acc: 0.4536, Val F1: 0.4537, Val MCC: -0.0902, Epoch Time: 2.81s, Total Time: 1675.19s
# Epoch 569, Train Loss: 0.6031, Train Acc: 0.6667, Train F1: 0.6649, Train MCC: 0.3314, Val Loss: 0.7770, Val Acc: 0.4510, Val F1: 0.4510, Val MCC: -0.0947, Epoch Time: 2.73s, Total Time: 1677.92s
# Epoch 570, Train Loss: 0.6030, Train Acc: 0.6670, Train F1: 0.6654, Train MCC: 0.3320, Val Loss: 0.7833, Val Acc: 0.4516, Val F1: 0.4509, Val MCC: -0.0919, Epoch Time: 2.72s, Total Time: 1680.64s
# Epoch 571, Train Loss: 0.6025, Train Acc: 0.6680, Train F1: 0.6659, Train MCC: 0.3343, Val Loss: 0.7746, Val Acc: 0.4485, Val F1: 0.4478, Val MCC: -0.0979, Epoch Time: 2.77s, Total Time: 1683.41s
# Epoch 572, Train Loss: 0.6023, Train Acc: 0.6676, Train F1: 0.6662, Train MCC: 0.3330, Val Loss: 0.8020, Val Acc: 0.4108, Val F1: 0.4036, Val MCC: -0.1694, Epoch Time: 2.89s, Total Time: 1686.30s
# Epoch 573, Train Loss: 0.6030, Train Acc: 0.6669, Train F1: 0.6652, Train MCC: 0.3318, Val Loss: 0.8074, Val Acc: 0.4278, Val F1: 0.4244, Val MCC: -0.1367, Epoch Time: 2.84s, Total Time: 1689.14s
# Epoch 574, Train Loss: 0.6044, Train Acc: 0.6658, Train F1: 0.6642, Train MCC: 0.3295, Val Loss: 0.7787, Val Acc: 0.4108, Val F1: 0.4045, Val MCC: -0.1698, Epoch Time: 2.91s, Total Time: 1692.04s
# Epoch 575, Train Loss: 0.6031, Train Acc: 0.6674, Train F1: 0.6660, Train MCC: 0.3327, Val Loss: 0.7917, Val Acc: 0.4390, Val F1: 0.4375, Val MCC: -0.1160, Epoch Time: 2.92s, Total Time: 1694.96s
# Epoch 576, Train Loss: 0.6028, Train Acc: 0.6669, Train F1: 0.6650, Train MCC: 0.3319, Val Loss: 0.7725, Val Acc: 0.4421, Val F1: 0.4407, Val MCC: -0.1096, Epoch Time: 2.85s, Total Time: 1697.81s
# Epoch 577, Train Loss: 0.6021, Train Acc: 0.6680, Train F1: 0.6663, Train MCC: 0.3339, Val Loss: 0.8272, Val Acc: 0.3930, Val F1: 0.3780, Val MCC: -0.2059, Epoch Time: 2.83s, Total Time: 1700.64s
# Epoch 578, Train Loss: 0.6026, Train Acc: 0.6682, Train F1: 0.6667, Train MCC: 0.3343, Val Loss: 0.7937, Val Acc: 0.4415, Val F1: 0.4403, Val MCC: -0.1113, Epoch Time: 2.91s, Total Time: 1703.55s
# Epoch 579, Train Loss: 0.6040, Train Acc: 0.6664, Train F1: 0.6644, Train MCC: 0.3308, Val Loss: 0.8177, Val Acc: 0.4798, Val F1: 0.4676, Val MCC: -0.0229, Epoch Time: 2.89s, Total Time: 1706.44s
# Epoch 580, Train Loss: 0.6046, Train Acc: 0.6663, Train F1: 0.6643, Train MCC: 0.3307, Val Loss: 0.8290, Val Acc: 0.4165, Val F1: 0.4112, Val MCC: -0.1584, Epoch Time: 2.88s, Total Time: 1709.32s
# Epoch 581, Train Loss: 0.6049, Train Acc: 0.6650, Train F1: 0.6629, Train MCC: 0.3281, Val Loss: 0.8152, Val Acc: 0.4411, Val F1: 0.4207, Val MCC: -0.1027, Epoch Time: 2.87s, Total Time: 1712.19s
# Epoch 582, Train Loss: 0.6057, Train Acc: 0.6663, Train F1: 0.6645, Train MCC: 0.3306, Val Loss: 0.8326, Val Acc: 0.4335, Val F1: 0.4324, Val MCC: -0.1274, Epoch Time: 2.87s, Total Time: 1715.06s
# Epoch 583, Train Loss: 0.6036, Train Acc: 0.6683, Train F1: 0.6656, Train MCC: 0.3351, Val Loss: 0.7666, Val Acc: 0.4274, Val F1: 0.4248, Val MCC: -0.1379, Epoch Time: 2.85s, Total Time: 1717.91s
# Epoch 584, Train Loss: 0.6020, Train Acc: 0.6688, Train F1: 0.6668, Train MCC: 0.3357, Val Loss: 0.7840, Val Acc: 0.4375, Val F1: 0.4354, Val MCC: -0.1180, Epoch Time: 4.27s, Total Time: 1722.19s
# Epoch 585, Train Loss: 0.6019, Train Acc: 0.6688, Train F1: 0.6670, Train MCC: 0.3357, Val Loss: 0.7821, Val Acc: 0.4744, Val F1: 0.4573, Val MCC: -0.0316, Epoch Time: 2.79s, Total Time: 1724.98s
# Epoch 586, Train Loss: 0.6019, Train Acc: 0.6687, Train F1: 0.6668, Train MCC: 0.3355, Val Loss: 0.7587, Val Acc: 0.4397, Val F1: 0.4374, Val MCC: -0.1136, Epoch Time: 2.84s, Total Time: 1727.82s
# Epoch 587, Train Loss: 0.6017, Train Acc: 0.6683, Train F1: 0.6662, Train MCC: 0.3349, Val Loss: 0.7780, Val Acc: 0.4468, Val F1: 0.4453, Val MCC: -0.1000, Epoch Time: 2.87s, Total Time: 1730.69s
# Epoch 588, Train Loss: 0.6016, Train Acc: 0.6685, Train F1: 0.6669, Train MCC: 0.3350, Val Loss: 0.7945, Val Acc: 0.4329, Val F1: 0.4312, Val MCC: -0.1278, Epoch Time: 2.79s, Total Time: 1733.47s
# Epoch 589, Train Loss: 0.6018, Train Acc: 0.6686, Train F1: 0.6669, Train MCC: 0.3351, Val Loss: 0.7737, Val Acc: 0.4321, Val F1: 0.4306, Val MCC: -0.1298, Epoch Time: 2.83s, Total Time: 1736.31s
# Epoch 590, Train Loss: 0.6014, Train Acc: 0.6688, Train F1: 0.6664, Train MCC: 0.3359, Val Loss: 0.8091, Val Acc: 0.4371, Val F1: 0.4359, Val MCC: -0.1202, Epoch Time: 2.82s, Total Time: 1739.12s
# Epoch 591, Train Loss: 0.6017, Train Acc: 0.6689, Train F1: 0.6674, Train MCC: 0.3358, Val Loss: 0.7995, Val Acc: 0.4334, Val F1: 0.4319, Val MCC: -0.1272, Epoch Time: 2.85s, Total Time: 1741.98s
# Epoch 592, Train Loss: 0.6038, Train Acc: 0.6684, Train F1: 0.6659, Train MCC: 0.3353, Val Loss: 0.7701, Val Acc: 0.4093, Val F1: 0.4031, Val MCC: -0.1727, Epoch Time: 2.80s, Total Time: 1744.78s
# Epoch 593, Train Loss: 0.6038, Train Acc: 0.6665, Train F1: 0.6655, Train MCC: 0.3309, Val Loss: 0.7953, Val Acc: 0.4320, Val F1: 0.4286, Val MCC: -0.1279, Epoch Time: 2.74s, Total Time: 1747.51s
# Epoch 594, Train Loss: 0.6067, Train Acc: 0.6612, Train F1: 0.6603, Train MCC: 0.3201, Val Loss: 0.8189, Val Acc: 0.4433, Val F1: 0.4427, Val MCC: -0.1085, Epoch Time: 2.73s, Total Time: 1750.24s
# Epoch 595, Train Loss: 0.6051, Train Acc: 0.6647, Train F1: 0.6625, Train MCC: 0.3276, Val Loss: 0.8465, Val Acc: 0.4158, Val F1: 0.4096, Val MCC: -0.1595, Epoch Time: 2.76s, Total Time: 1753.00s
# Epoch 596, Train Loss: 0.6080, Train Acc: 0.6638, Train F1: 0.6612, Train MCC: 0.3259, Val Loss: 0.8505, Val Acc: 0.4137, Val F1: 0.4072, Val MCC: -0.1636, Epoch Time: 2.74s, Total Time: 1755.74s
# Epoch 597, Train Loss: 0.6041, Train Acc: 0.6677, Train F1: 0.6667, Train MCC: 0.3333, Val Loss: 0.8359, Val Acc: 0.3940, Val F1: 0.3800, Val MCC: -0.2037, Epoch Time: 2.79s, Total Time: 1758.53s
# Epoch 598, Train Loss: 0.6027, Train Acc: 0.6675, Train F1: 0.6650, Train MCC: 0.3334, Val Loss: 0.8438, Val Acc: 0.3907, Val F1: 0.3769, Val MCC: -0.2107, Epoch Time: 2.86s, Total Time: 1761.39s
# Epoch 599, Train Loss: 0.6015, Train Acc: 0.6691, Train F1: 0.6674, Train MCC: 0.3363, Val Loss: 0.8279, Val Acc: 0.3954, Val F1: 0.3809, Val MCC: -0.2007, Epoch Time: 2.89s, Total Time: 1764.28s
# Epoch 600, Train Loss: 0.6007, Train Acc: 0.6693, Train F1: 0.6674, Train MCC: 0.3367, Val Loss: 0.8130, Val Acc: 0.4027, Val F1: 0.3918, Val MCC: -0.1856, Epoch Time: 2.87s, Total Time: 1767.15s
# Best Val Accuracy: 0.5669

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GATConv
import os
import time
from sklearn.metrics import f1_score, matthews_corrcoef
import numpy as np

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

class GATGRUModel(nn.Module):
    def __init__(self, input_dim, gru_hidden_dim, gat_hidden_dim, num_heads, output_dim=2):
        super(GATGRUModel, self).__init__()
        self.gru = nn.GRU(input_dim, gru_hidden_dim, batch_first=True)
        self.gat1 = GATConv(gru_hidden_dim, gat_hidden_dim, heads=num_heads, concat=True)
        self.gat2 = GATConv(gat_hidden_dim * num_heads, gat_hidden_dim, heads=1, concat=True)
        self.fc = nn.Linear(gat_hidden_dim, output_dim)

    def forward(self, x, edge_index):
        gru_out, _ = self.gru(x)
        gru_out = gru_out[:, -1, :]
        gat_out = F.relu(self.gat1(gru_out, edge_index))
        gat_out = self.gat2(gat_out, edge_index)
        out = self.fc(gat_out)
        return out

input_dim = 5  # Open, High, Low, Close, Volume
gru_hidden_dim = 64
gat_hidden_dim = 64
num_heads = 2

save_dir = './w_7_NYSE_graph_data'
train_windows = 137
val_windows = 9
test_windows = 35

model = GATGRUModel(input_dim, gru_hidden_dim, gat_hidden_dim, num_heads, output_dim=2)
model.load_state_dict(torch.load('GAT+GRU_w7_gru64_gat64_head2.pt', map_location=device))
model.to(device)
model.eval()  
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

val_loss, val_accuracy, val_count = 0.0, 0.0, 0
val_predictions, val_labels = [], []
with torch.no_grad():
    for i in range(val_windows):
        graph_data = torch.load(os.path.join(save_dir, 'val', f'graph_{i}.pt'))
        X, edge_index, Y = graph_data['X'], graph_data['A'], graph_data['Y']
        X, edge_index, Y = X.to(device), edge_index.to(device), Y.to(device)
        
        out = model(X, edge_index)
        loss = criterion(out, Y)
        _, predicted = torch.max(out, 1)
        val_loss += loss.item()
        val_accuracy += (predicted == Y).float().mean().item()
        val_count += 1
        
        val_predictions.extend(predicted.cpu().numpy())
        val_labels.extend(Y.cpu().numpy())

# 平均指标
avg_val_loss = val_loss / val_count if val_count > 0 else 0
avg_val_accuracy = val_accuracy / val_count if val_count > 0 else 0

# --- Calculate F1-score and MCC ---
val_f1 = f1_score(val_labels, val_predictions, average='weighted')
val_mcc = matthews_corrcoef(val_labels, val_predictions)

# --- Updated print statement with F1 and MCC ---
print(
      f'Val Loss: {avg_val_loss:.4f}, Val Acc: {avg_val_accuracy:.4f}, '
      f'Val F1: {val_f1:.4f}, Val MCC: {val_mcc:.4f} ')
# Out:
# Using device: cuda
# Val Loss: 0.7098, Val Acc: 0.5669, Val F1: 0.5644, Val MCC: 0.1456

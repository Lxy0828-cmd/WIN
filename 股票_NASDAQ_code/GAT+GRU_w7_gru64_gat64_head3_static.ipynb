# %%
import pandas as pd
import glob
import os
import torch
import numpy as np
from datetime import datetime
from scipy.stats import pearsonr

# 获取所有 CSV 文件
data_dir = 'NASDAQ/'
csv_files = glob.glob(os.path.join(data_dir, 'NASDAQ_*_30Y.csv'))

# 加载公司数据
companies_data = {}
for f in csv_files:
    try:
        company_name = os.path.basename(f).split('_')[1]
        df = pd.read_csv(f)
        df['Date'] = pd.to_datetime(df['Date'], utc=True)
        df['Date'] = df['Date'].dt.tz_convert(None)
        companies_data[company_name] = df
    except Exception as e:
        print(f"Error loading {f}: {e}")

# 定义日期范围
train_start = datetime.strptime('2013-01-01', '%Y-%m-%d')
train_end = datetime.strptime('2013-8-31', '%Y-%m-%d')
val_start = datetime.strptime('2013-9-01', '%Y-%m-%d')
val_end = datetime.strptime('2013-10-31', '%Y-%m-%d')
test_start = datetime.strptime('2013-11-01', '%Y-%m-%d')
test_end = datetime.strptime('2013-12-31', '%Y-%m-%d')

# 按日期范围划分数据
train_data = {}
val_data = {}
test_data = {}
for company, df in companies_data.items():
    train_data[company] = df[(df['Date'] >= train_start) & (df['Date'] <= train_end)][['Date', 'Open', 'High', 'Low', 'Close', 'Volume']].copy()
    val_data[company] = df[(df['Date'] >= val_start) & (df['Date'] <= val_end)][['Date', 'Open', 'High', 'Low', 'Close', 'Volume']].copy()
    test_data[company] = df[(df['Date'] >= test_start) & (df['Date'] <= test_end)][['Date', 'Open', 'High', 'Low', 'Close', 'Volume']].copy()

company_names = list(companies_data.keys())
num_companies = len(company_names)

# %%
def pearsonr_torch(x, y, device='cuda'):
    """
    计算两个序列的皮尔逊相关系数（GPU 加速）
    x, y: shape (seq_len,) 的 PyTorch 张量
    """
    x = x.to(device)
    y = y.to(device)
    mean_x = torch.mean(x)
    mean_y = torch.mean(y)
    xm = x - mean_x
    ym = y - mean_y
    cov_xy = torch.sum(xm * ym)
    std_x = torch.sqrt(torch.sum(xm ** 2))
    std_y = torch.sqrt(torch.sum(ym ** 2))
    corr = cov_xy / (std_x * std_y + 1e-10)  # 避免除以零
    return corr

def create_graph_data(dataset, company_names, seq_len, save_dir, split, corr_threshold=0.7, device='cuda'):
    if not os.path.exists(os.path.join(save_dir, split)):
        os.makedirs(os.path.join(save_dir, split))
    
    num_companies = len(company_names)
    num_windows = 0
    
    # 检查是否有可用的 GPU
    if device == 'cuda' and not torch.cuda.is_available():
        print("警告：未检测到 GPU，使用 CPU 进行计算")
        device = 'cpu'
    
    # 确定最小数据长度
    min_length = min(len(dataset[company]) for company in company_names if not dataset[company].empty)
    if min_length < seq_len + 1:
        print(f"警告：{split} 集数据不足 (min_length={min_length})")
        return 0
    
    # 按行索引生成时间窗口
    for i in range(min_length - seq_len):
        X = []
        Y = []
        valid_companies = []
        close_prices_window = []
        
        # 收集当前窗口的数据
        for j, company in enumerate(company_names):
            df = dataset[company]
            if len(df) < seq_len + 1:
                continue
            
            window_data = df.iloc[i:i+seq_len]
            if len(window_data) == seq_len:
                features = window_data[['Open', 'High', 'Low', 'Close', 'Volume']].values
                X.append(features)
                close_prices_window.append(window_data['Close'].values)
                
                current_close = window_data['Close'].iloc[-1]
                next_data = df.iloc[i+seq_len] if i+seq_len < len(df) else None
                if next_data is not None:
                    next_close = next_data['Close']
                    label = 1 if next_close > current_close else 0
                    Y.append(label)
                    valid_companies.append(j)
        
        # 仅当所有公司数据完整时继续
        if len(X) == num_companies and len(Y) == num_companies:
            # 计算当前窗口的相关性矩阵
            adj_matrix = np.zeros((num_companies, num_companies))
            close_prices_window = np.array(close_prices_window)  # (num_companies, seq_len)
            close_prices_tensor = torch.tensor(close_prices_window, dtype=torch.float32)
            
            for m in range(num_companies):
                for n in range(m + 1, num_companies):
                    if len(close_prices_window[m]) > 1 and len(close_prices_window[n]) > 1:
                        corr = pearsonr_torch(close_prices_tensor[m], close_prices_tensor[n], device)
                        if abs(corr) > corr_threshold:
                            adj_matrix[m, n] = 1
                            adj_matrix[n, m] = 1
            
            # 生成 edge_index
            indices = np.vstack(np.where(adj_matrix > 0))
            edge_index = torch.from_numpy(indices).long()
            
            # 保存图数据
            X = torch.from_numpy(np.array(X, dtype=np.float32))  # (num_companies, seq_len, 5)
            Y = torch.tensor(Y, dtype=torch.long)   # (num_companies,)
            graph_data = {'X': X, 'A': edge_index, 'Y': Y}
            torch.save(graph_data, os.path.join(save_dir, split, f'graph_{num_windows}.pt'))
            num_windows += 1
    
    return num_windows

# 创建并保存图数据
save_dir = './w_7_NASDAQ_graph_data'
seq_len = 7
corr_threshold = 0.7
device = 'cuda' if torch.cuda.is_available() else 'cpu'
train_windows = create_graph_data(train_data, company_names, seq_len, save_dir=save_dir, split='train', corr_threshold=corr_threshold, device=device)
# val_windows = create_graph_data(val_data, company_names, seq_len, save_dir=save_dir, split='val', corr_threshold=corr_threshold, device=device)
# test_windows = create_graph_data(test_data, company_names, seq_len, save_dir=save_dir, split='test', corr_threshold=corr_threshold, device=device)
# print(f"创建了 {train_windows} 个训练图、{val_windows} 个验证图、{test_windows} 个测试图数据文件。")

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GATConv
import os
import time
from sklearn.metrics import f1_score, matthews_corrcoef
import numpy as np

# 检查 GPU 可用性
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

class GATGRUModel(nn.Module):
    def __init__(self, input_dim, gru_hidden_dim, gat_hidden_dim, num_heads, output_dim=2):
        super(GATGRUModel, self).__init__()
        self.gru = nn.GRU(input_dim, gru_hidden_dim, batch_first=True)
        self.gat1 = GATConv(gru_hidden_dim, gat_hidden_dim, heads=num_heads, concat=True)
        self.gat2 = GATConv(gat_hidden_dim * num_heads, gat_hidden_dim, heads=1, concat=True)
        self.fc = nn.Linear(gat_hidden_dim, output_dim)

    def forward(self, x, edge_index):
        gru_out, _ = self.gru(x)
        gru_out = gru_out[:, -1, :]
        gat_out = F.relu(self.gat1(gru_out, edge_index))
        gat_out = self.gat2(gat_out, edge_index)
        out = self.fc(gat_out)
        return out

def train_model(model, save_dir, train_windows, val_windows, test_windows, epochs=50):
    # 将模型移动到 GPU
    model = model.to(device)
    
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.CrossEntropyLoss()
    
    # 加载训练集中第一张图的边索引
    first_graph_data = torch.load(os.path.join(save_dir, 'train', 'graph_0.pt'))
    fixed_edge_index = first_graph_data['A'].to(device)  # 固定边索引并移到 GPU
    
    start_time = time.time()  # 记录训练开始时间
    best_val_accuracy = 0.0  # Track the best validation accuracy
    
    for epoch in range(epochs):
        epoch_start = time.time()  # 记录该 epoch 开始时间

        # 训练
        model.train()
        train_loss, train_accuracy, train_count = 0.0, 0.0, 0
        train_predictions, train_labels = [], []
        
        for i in range(train_windows):
            graph_data = torch.load(os.path.join(save_dir, 'train', f'graph_{i}.pt'))
            X, Y = graph_data['X'], graph_data['Y']
            X, Y = X.to(device), Y.to(device)
            
            optimizer.zero_grad()
            out = model(X, fixed_edge_index)  # 使用固定的边索引
            loss = criterion(out, Y)
            loss.backward()
            optimizer.step()
            
            _, predicted = torch.max(out, 1)
            train_loss += loss.item()
            train_accuracy += (predicted == Y).float().mean().item()
            train_count += 1
            
            train_predictions.extend(predicted.cpu().numpy())
            train_labels.extend(Y.cpu().numpy())
            
        # 验证
        model.eval()
        val_loss, val_accuracy, val_count = 0.0, 0.0, 0
        val_predictions, val_labels = [], []
        
        with torch.no_grad():
            for i in range(val_windows):
                graph_data = torch.load(os.path.join(save_dir, 'val', f'graph_{i}.pt'))
                X, Y = graph_data['X'], graph_data['Y']
                X, Y = X.to(device), Y.to(device)
                
                out = model(X, fixed_edge_index)  # 使用固定的边索引
                loss = criterion(out, Y)
                _, predicted = torch.max(out, 1)
                val_loss += loss.item()
                val_accuracy += (predicted == Y).float().mean().item()
                val_count += 1
                
                val_predictions.extend(predicted.cpu().numpy())
                val_labels.extend(Y.cpu().numpy())
        
        # 平均指标
        avg_train_loss = train_loss / train_count if train_count > 0 else 0
        avg_train_accuracy = train_accuracy / train_count if train_count > 0 else 0
        avg_val_loss = val_loss / val_count if val_count > 0 else 0
        avg_val_accuracy = val_accuracy / val_count if val_count > 0 else 0
        
        # 计算 F1 分数和 MCC
        train_f1 = f1_score(train_labels, train_predictions, average='weighted')
        train_mcc = matthews_corrcoef(train_labels, train_predictions)
        val_f1 = f1_score(val_labels, val_predictions, average='weighted')
        val_mcc = matthews_corrcoef(val_labels, val_predictions)
        
        # 保存最佳模型
        if avg_val_accuracy > best_val_accuracy:
            torch.save(model.state_dict(), 'GAT+GRU_w7_gru64_gat64_head3_static.pt')
            best_val_accuracy = avg_val_accuracy
            
        # 时间统计
        epoch_time = time.time() - epoch_start
        total_time = time.time() - start_time
        
        # 打印指标
        print(f'Epoch {epoch+1}, '
              f'Train Loss: {avg_train_loss:.4f}, Train Acc: {avg_train_accuracy:.4f}, '
              f'Train F1: {train_f1:.4f}, Train MCC: {train_mcc:.4f}, '
              f'Val Loss: {avg_val_loss:.4f}, Val Acc: {avg_val_accuracy:.4f}, '
              f'Val F1: {val_f1:.4f}, Val MCC: {val_mcc:.4f}, '
              f'Epoch Time: {epoch_time:.2f}s, Total Time: {total_time:.2f}s')
    
    print(f'Best Val Accuracy: {best_val_accuracy:.4f}')

# 参数
input_dim = 5  # Open, High, Low, Close, Volume
gru_hidden_dim = 64
gat_hidden_dim = 64
num_heads = 3

save_dir = './w_7_NASDAQ_graph_data'
train_windows = 149
val_windows = 28
test_windows = 35

# 初始化模型
model = GATGRUModel(input_dim, gru_hidden_dim, gat_hidden_dim, num_heads, output_dim=2)

train_model(model, save_dir, train_windows, val_windows, test_windows)
# Out:
# Using device: cuda
# Epoch 1, Train Loss: 0.7014, Train Acc: 0.5244, Train F1: 0.5165, Train MCC: 0.0350, Val Loss: 0.7125, Val Acc: 0.4672, Val F1: 0.2975, Val MCC: 0.0000, Epoch Time: 2.88s, Total Time: 2.88s
# Epoch 2, Train Loss: 0.6996, Train Acc: 0.5026, Train F1: 0.4893, Train MCC: -0.0144, Val Loss: 0.7094, Val Acc: 0.4720, Val F1: 0.3157, Val MCC: 0.0331, Epoch Time: 2.73s, Total Time: 5.61s
# Epoch 3, Train Loss: 0.6998, Train Acc: 0.5020, Train F1: 0.4663, Train MCC: -0.0299, Val Loss: 0.6908, Val Acc: 0.5328, Val F1: 0.3705, Val MCC: 0.0000, Epoch Time: 2.56s, Total Time: 8.16s
# Epoch 4, Train Loss: 0.6936, Train Acc: 0.5288, Train F1: 0.3658, Train MCC: 0.0000, Val Loss: 0.6904, Val Acc: 0.5328, Val F1: 0.3705, Val MCC: 0.0000, Epoch Time: 2.67s, Total Time: 10.84s
# Epoch 5, Train Loss: 0.6935, Train Acc: 0.5280, Train F1: 0.3660, Train MCC: -0.0180, Val Loss: 0.6904, Val Acc: 0.5340, Val F1: 0.3765, Val MCC: 0.0210, Epoch Time: 2.72s, Total Time: 13.56s
# Epoch 6, Train Loss: 0.6934, Train Acc: 0.5277, Train F1: 0.3781, Train MCC: -0.0012, Val Loss: 0.6902, Val Acc: 0.5330, Val F1: 0.3721, Val MCC: 0.0061, Epoch Time: 2.88s, Total Time: 16.44s
# Epoch 7, Train Loss: 0.6928, Train Acc: 0.5275, Train F1: 0.3685, Train MCC: -0.0134, Val Loss: 0.6901, Val Acc: 0.5347, Val F1: 0.3786, Val MCC: 0.0285, Epoch Time: 2.76s, Total Time: 19.21s
# Epoch 8, Train Loss: 0.6919, Train Acc: 0.5273, Train F1: 0.3732, Train MCC: -0.0083, Val Loss: 0.6897, Val Acc: 0.5366, Val F1: 0.3980, Val MCC: 0.0339, Epoch Time: 2.99s, Total Time: 22.19s
# Epoch 9, Train Loss: 0.6914, Train Acc: 0.5265, Train F1: 0.3835, Train MCC: -0.0056, Val Loss: 0.6899, Val Acc: 0.5383, Val F1: 0.4063, Val MCC: 0.0425, Epoch Time: 2.90s, Total Time: 25.09s
# Epoch 10, Train Loss: 0.6919, Train Acc: 0.5264, Train F1: 0.3945, Train MCC: -0.0007, Val Loss: 0.6894, Val Acc: 0.5411, Val F1: 0.4318, Val MCC: 0.0509, Epoch Time: 3.02s, Total Time: 28.11s
# Epoch 11, Train Loss: 0.6914, Train Acc: 0.5286, Train F1: 0.4086, Train MCC: 0.0134, Val Loss: 0.6896, Val Acc: 0.5408, Val F1: 0.4350, Val MCC: 0.0490, Epoch Time: 2.45s, Total Time: 30.56s
# Epoch 12, Train Loss: 0.6910, Train Acc: 0.5309, Train F1: 0.4198, Train MCC: 0.0239, Val Loss: 0.6877, Val Acc: 0.5511, Val F1: 0.4745, Val MCC: 0.0803, Epoch Time: 2.67s, Total Time: 33.23s
# Epoch 13, Train Loss: 0.6910, Train Acc: 0.5286, Train F1: 0.4124, Train MCC: 0.0139, Val Loss: 0.6888, Val Acc: 0.5421, Val F1: 0.4353, Val MCC: 0.0545, Epoch Time: 2.60s, Total Time: 35.84s
# Epoch 14, Train Loss: 0.6904, Train Acc: 0.5330, Train F1: 0.4233, Train MCC: 0.0324, Val Loss: 0.6897, Val Acc: 0.5369, Val F1: 0.4403, Val MCC: 0.0348, Epoch Time: 2.81s, Total Time: 38.65s
# Epoch 15, Train Loss: 0.6907, Train Acc: 0.5305, Train F1: 0.4270, Train MCC: 0.0235, Val Loss: 0.6892, Val Acc: 0.5593, Val F1: 0.5092, Val MCC: 0.0999, Epoch Time: 2.17s, Total Time: 40.82s
# Epoch 16, Train Loss: 0.6904, Train Acc: 0.5284, Train F1: 0.4688, Train MCC: 0.0249, Val Loss: 0.6874, Val Acc: 0.5585, Val F1: 0.5001, Val MCC: 0.0989, Epoch Time: 2.06s, Total Time: 42.88s
# Epoch 17, Train Loss: 0.6891, Train Acc: 0.5320, Train F1: 0.4405, Train MCC: 0.0300, Val Loss: 0.6903, Val Acc: 0.5357, Val F1: 0.4238, Val MCC: 0.0290, Epoch Time: 2.04s, Total Time: 44.92s
# Epoch 18, Train Loss: 0.6913, Train Acc: 0.5336, Train F1: 0.4241, Train MCC: 0.0350, Val Loss: 0.6879, Val Acc: 0.5581, Val F1: 0.4887, Val MCC: 0.0999, Epoch Time: 1.93s, Total Time: 46.85s
# Epoch 19, Train Loss: 0.6905, Train Acc: 0.5334, Train F1: 0.4078, Train MCC: 0.0351, Val Loss: 0.6855, Val Acc: 0.5607, Val F1: 0.4998, Val MCC: 0.1055, Epoch Time: 1.83s, Total Time: 48.69s
# Epoch 20, Train Loss: 0.6884, Train Acc: 0.5399, Train F1: 0.4641, Train MCC: 0.0555, Val Loss: 0.6970, Val Acc: 0.5641, Val F1: 0.4964, Val MCC: 0.1173, Epoch Time: 1.84s, Total Time: 50.52s
# Epoch 21, Train Loss: 0.6894, Train Acc: 0.5433, Train F1: 0.4803, Train MCC: 0.0649, Val Loss: 0.6938, Val Acc: 0.5225, Val F1: 0.5229, Val MCC: 0.0429, Epoch Time: 1.83s, Total Time: 52.35s
# Epoch 22, Train Loss: 0.6888, Train Acc: 0.5345, Train F1: 0.4367, Train MCC: 0.0381, Val Loss: 0.6900, Val Acc: 0.5702, Val F1: 0.5236, Val MCC: 0.1274, Epoch Time: 1.96s, Total Time: 54.31s
# Epoch 23, Train Loss: 0.6872, Train Acc: 0.5436, Train F1: 0.4797, Train MCC: 0.0657, Val Loss: 0.6863, Val Acc: 0.5731, Val F1: 0.5252, Val MCC: 0.1354, Epoch Time: 1.86s, Total Time: 56.17s
# Epoch 24, Train Loss: 0.6893, Train Acc: 0.5399, Train F1: 0.4725, Train MCC: 0.0554, Val Loss: 0.6918, Val Acc: 0.5276, Val F1: 0.4575, Val MCC: 0.0120, Epoch Time: 1.85s, Total Time: 58.02s
# Epoch 25, Train Loss: 0.6874, Train Acc: 0.5321, Train F1: 0.4349, Train MCC: 0.0297, Val Loss: 0.6851, Val Acc: 0.5683, Val F1: 0.5233, Val MCC: 0.1223, Epoch Time: 2.01s, Total Time: 60.02s
# Epoch 26, Train Loss: 0.6842, Train Acc: 0.5577, Train F1: 0.5152, Train MCC: 0.1011, Val Loss: 0.6877, Val Acc: 0.5458, Val F1: 0.5343, Val MCC: 0.1194, Epoch Time: 2.19s, Total Time: 62.21s
# Epoch 27, Train Loss: 0.6836, Train Acc: 0.5511, Train F1: 0.5072, Train MCC: 0.0846, Val Loss: 0.6928, Val Acc: 0.5405, Val F1: 0.5115, Val MCC: 0.0562, Epoch Time: 1.94s, Total Time: 64.15s
# Epoch 28, Train Loss: 0.6849, Train Acc: 0.5491, Train F1: 0.4810, Train MCC: 0.0819, Val Loss: 0.6801, Val Acc: 0.5835, Val F1: 0.5742, Val MCC: 0.1547, Epoch Time: 1.98s, Total Time: 66.13s
# Epoch 29, Train Loss: 0.6799, Train Acc: 0.5610, Train F1: 0.5162, Train MCC: 0.1097, Val Loss: 0.6887, Val Acc: 0.5759, Val F1: 0.5735, Val MCC: 0.1432, Epoch Time: 2.06s, Total Time: 68.19s
# Epoch 30, Train Loss: 0.6776, Train Acc: 0.5674, Train F1: 0.5444, Train MCC: 0.1222, Val Loss: 0.6882, Val Acc: 0.5439, Val F1: 0.5421, Val MCC: 0.0985, Epoch Time: 2.14s, Total Time: 70.33s
# Epoch 31, Train Loss: 0.6777, Train Acc: 0.5692, Train F1: 0.5394, Train MCC: 0.1271, Val Loss: 0.7002, Val Acc: 0.5375, Val F1: 0.5367, Val MCC: 0.0687, Epoch Time: 2.05s, Total Time: 72.38s
# Epoch 32, Train Loss: 0.6777, Train Acc: 0.5664, Train F1: 0.5363, Train MCC: 0.1204, Val Loss: 0.6942, Val Acc: 0.5664, Val F1: 0.5599, Val MCC: 0.1205, Epoch Time: 2.07s, Total Time: 74.45s
# Epoch 33, Train Loss: 0.6781, Train Acc: 0.5566, Train F1: 0.5355, Train MCC: 0.0981, Val Loss: 0.7122, Val Acc: 0.5312, Val F1: 0.5249, Val MCC: 0.0482, Epoch Time: 2.02s, Total Time: 76.47s
# Epoch 34, Train Loss: 0.6778, Train Acc: 0.5614, Train F1: 0.5490, Train MCC: 0.1101, Val Loss: 0.6958, Val Acc: 0.5899, Val F1: 0.5758, Val MCC: 0.1678, Epoch Time: 2.01s, Total Time: 78.48s
# Epoch 35, Train Loss: 0.6733, Train Acc: 0.5730, Train F1: 0.5610, Train MCC: 0.1348, Val Loss: 0.6876, Val Acc: 0.5805, Val F1: 0.5794, Val MCC: 0.1546, Epoch Time: 2.18s, Total Time: 80.66s
# Epoch 36, Train Loss: 0.6746, Train Acc: 0.5681, Train F1: 0.5604, Train MCC: 0.1255, Val Loss: 0.7093, Val Acc: 0.5414, Val F1: 0.5406, Val MCC: 0.0763, Epoch Time: 1.99s, Total Time: 82.65s
# Epoch 37, Train Loss: 0.6723, Train Acc: 0.5854, Train F1: 0.5788, Train MCC: 0.1617, Val Loss: 0.7153, Val Acc: 0.5380, Val F1: 0.5363, Val MCC: 0.0678, Epoch Time: 1.91s, Total Time: 84.56s
# Epoch 38, Train Loss: 0.6693, Train Acc: 0.5834, Train F1: 0.5718, Train MCC: 0.1568, Val Loss: 0.7066, Val Acc: 0.5583, Val F1: 0.5569, Val MCC: 0.1093, Epoch Time: 1.85s, Total Time: 86.41s
# Epoch 39, Train Loss: 0.6672, Train Acc: 0.5923, Train F1: 0.5840, Train MCC: 0.1758, Val Loss: 0.7106, Val Acc: 0.5368, Val F1: 0.5361, Val MCC: 0.0808, Epoch Time: 1.83s, Total Time: 88.24s
# Epoch 40, Train Loss: 0.6656, Train Acc: 0.5925, Train F1: 0.5846, Train MCC: 0.1762, Val Loss: 0.7198, Val Acc: 0.5324, Val F1: 0.5329, Val MCC: 0.0649, Epoch Time: 1.79s, Total Time: 90.04s
# Epoch 41, Train Loss: 0.6632, Train Acc: 0.5970, Train F1: 0.5880, Train MCC: 0.1857, Val Loss: 0.7008, Val Acc: 0.5537, Val F1: 0.5540, Val MCC: 0.1051, Epoch Time: 1.86s, Total Time: 91.90s
# Epoch 42, Train Loss: 0.6609, Train Acc: 0.5990, Train F1: 0.5880, Train MCC: 0.1900, Val Loss: 0.7120, Val Acc: 0.5471, Val F1: 0.5475, Val MCC: 0.0929, Epoch Time: 1.92s, Total Time: 93.82s
# Epoch 43, Train Loss: 0.6601, Train Acc: 0.6087, Train F1: 0.6017, Train MCC: 0.2099, Val Loss: 0.7081, Val Acc: 0.5426, Val F1: 0.5430, Val MCC: 0.0874, Epoch Time: 1.80s, Total Time: 95.62s
# Epoch 44, Train Loss: 0.6612, Train Acc: 0.6018, Train F1: 0.5928, Train MCC: 0.1956, Val Loss: 0.7102, Val Acc: 0.5312, Val F1: 0.5309, Val MCC: 0.0684, Epoch Time: 1.81s, Total Time: 97.44s
# Epoch 45, Train Loss: 0.6574, Train Acc: 0.6092, Train F1: 0.5998, Train MCC: 0.2112, Val Loss: 0.7037, Val Acc: 0.5588, Val F1: 0.5591, Val MCC: 0.1202, Epoch Time: 1.94s, Total Time: 99.38s
# Epoch 46, Train Loss: 0.6547, Train Acc: 0.6152, Train F1: 0.6050, Train MCC: 0.2243, Val Loss: 0.7155, Val Acc: 0.5414, Val F1: 0.5383, Val MCC: 0.0959, Epoch Time: 2.21s, Total Time: 101.59s
# Epoch 47, Train Loss: 0.6553, Train Acc: 0.6160, Train F1: 0.6093, Train MCC: 0.2252, Val Loss: 0.7279, Val Acc: 0.5247, Val F1: 0.5235, Val MCC: 0.0578, Epoch Time: 2.04s, Total Time: 103.63s
# Epoch 48, Train Loss: 0.6521, Train Acc: 0.6174, Train F1: 0.6097, Train MCC: 0.2283, Val Loss: 0.7302, Val Acc: 0.5351, Val F1: 0.5326, Val MCC: 0.0821, Epoch Time: 2.09s, Total Time: 105.72s
# Epoch 49, Train Loss: 0.6526, Train Acc: 0.6191, Train F1: 0.6132, Train MCC: 0.2315, Val Loss: 0.7351, Val Acc: 0.5243, Val F1: 0.5239, Val MCC: 0.0547, Epoch Time: 2.07s, Total Time: 107.79s
# Epoch 50, Train Loss: 0.6508, Train Acc: 0.6243, Train F1: 0.6160, Train MCC: 0.2429, Val Loss: 0.7299, Val Acc: 0.5362, Val F1: 0.5335, Val MCC: 0.0847, Epoch Time: 2.03s, Total Time: 109.83s
# Best Val Accuracy: 0.5899

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GATConv
import os
import time
from sklearn.metrics import f1_score, matthews_corrcoef
import numpy as np

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

class GATGRUModel(nn.Module):
    def __init__(self, input_dim, gru_hidden_dim, gat_hidden_dim, num_heads, output_dim=2):
        super(GATGRUModel, self).__init__()
        self.gru = nn.GRU(input_dim, gru_hidden_dim, batch_first=True)
        self.gat1 = GATConv(gru_hidden_dim, gat_hidden_dim, heads=num_heads, concat=True)
        self.gat2 = GATConv(gat_hidden_dim * num_heads, gat_hidden_dim, heads=1, concat=True)
        self.fc = nn.Linear(gat_hidden_dim, output_dim)

    def forward(self, x, edge_index):
        gru_out, _ = self.gru(x)
        gru_out = gru_out[:, -1, :]
        gat_out = F.relu(self.gat1(gru_out, edge_index))
        gat_out = self.gat2(gat_out, edge_index)
        out = self.fc(gat_out)
        return out

input_dim = 5  # Open, High, Low, Close, Volume
gru_hidden_dim = 64
gat_hidden_dim = 64
num_heads = 3

save_dir = './w_7_NASDAQ_graph_data'
train_windows = 149
val_windows = 28
test_windows = 35

model = GATGRUModel(input_dim, gru_hidden_dim, gat_hidden_dim, num_heads, output_dim=2)
model.load_state_dict(torch.load('GAT+GRU_w7_gru64_gat64_head3_static.pt', map_location=device))
model.to(device)
model.eval()  
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

# 加载训练集中第一张图的边索引
first_graph_data = torch.load(os.path.join(save_dir, 'train', 'graph_0.pt'))
fixed_edge_index = first_graph_data['A'].to(device)  # 固定边索引并移到 GPU

val_loss, val_accuracy, val_count = 0.0, 0.0, 0
val_predictions, val_labels = [], []
with torch.no_grad():
    for i in range(val_windows):
        graph_data = torch.load(os.path.join(save_dir, 'val', f'graph_{i}.pt'))
        X, Y = graph_data['X'], graph_data['Y']
        X, Y = X.to(device), Y.to(device)
        
        out = model(X, fixed_edge_index)  # 使用固定的边索引
        loss = criterion(out, Y)
        _, predicted = torch.max(out, 1)
        val_loss += loss.item()
        val_accuracy += (predicted == Y).float().mean().item()
        val_count += 1
        
        val_predictions.extend(predicted.cpu().numpy())
        val_labels.extend(Y.cpu().numpy())

# 平均指标
avg_val_loss = val_loss / val_count if val_count > 0 else 0
avg_val_accuracy = val_accuracy / val_count if val_count > 0 else 0

# --- Calculate F1-score and MCC ---
val_f1 = f1_score(val_labels, val_predictions, average='weighted')
val_mcc = matthews_corrcoef(val_labels, val_predictions)

# --- Updated print statement with F1 and MCC ---
print(
      f'Val Loss: {avg_val_loss:.4f}, Val Acc: {avg_val_accuracy:.4f}, '
      f'Val F1: {val_f1:.4f}, Val MCC: {val_mcc:.4f} ')

total_params = sum(p.numel() for p in model.parameters())
# 可训练参数量
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
# 模型大小（参数 + buffer，以MB为单位）
param_size_bytes = sum(p.numel() * p.element_size() for p in model.parameters())
buffer_size_bytes = sum(b.numel() * b.element_size() for b in model.buffers())
model_size_mb = (param_size_bytes + buffer_size_bytes) / (1024 * 1024)

print(f"Total parameters: {total_params}")
print(f"Trainable parameters: {trainable_params}")
print(f"Model size (parameters + buffers): {model_size_mb:.2f} MB")
# Out:
# Using device: cuda
# Val Loss: 0.6958, Val Acc: 0.5899, Val F1: 0.5758, Val MCC: 0.1678
# Total parameters: 39106
# Trainable parameters: 39106
# Model size (parameters + buffers): 0.15 MB

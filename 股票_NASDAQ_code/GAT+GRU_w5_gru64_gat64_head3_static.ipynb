# %%
import pandas as pd
import glob
import os
import torch
import numpy as np
from datetime import datetime
from scipy.stats import pearsonr

# 获取所有 CSV 文件
data_dir = 'NASDAQ/'
csv_files = glob.glob(os.path.join(data_dir, 'NASDAQ_*_30Y.csv'))

# 加载公司数据
companies_data = {}
for f in csv_files:
    try:
        company_name = os.path.basename(f).split('_')[1]
        df = pd.read_csv(f)
        df['Date'] = pd.to_datetime(df['Date'], utc=True)
        df['Date'] = df['Date'].dt.tz_convert(None)
        companies_data[company_name] = df
    except Exception as e:
        print(f"Error loading {f}: {e}")

# 定义日期范围
train_start = datetime.strptime('2013-01-01', '%Y-%m-%d')
train_end = datetime.strptime('2013-8-31', '%Y-%m-%d')
val_start = datetime.strptime('2013-9-01', '%Y-%m-%d')
val_end = datetime.strptime('2013-10-31', '%Y-%m-%d')
test_start = datetime.strptime('2013-11-01', '%Y-%m-%d')
test_end = datetime.strptime('2013-12-31', '%Y-%m-%d')

# 按日期范围划分数据
train_data = {}
val_data = {}
test_data = {}
for company, df in companies_data.items():
    train_data[company] = df[(df['Date'] >= train_start) & (df['Date'] <= train_end)][['Date', 'Open', 'High', 'Low', 'Close', 'Volume']].copy()
    val_data[company] = df[(df['Date'] >= val_start) & (df['Date'] <= val_end)][['Date', 'Open', 'High', 'Low', 'Close', 'Volume']].copy()
    test_data[company] = df[(df['Date'] >= test_start) & (df['Date'] <= test_end)][['Date', 'Open', 'High', 'Low', 'Close', 'Volume']].copy()

company_names = list(companies_data.keys())
num_companies = len(company_names)

# %%
def pearsonr_torch(x, y, device='cuda'):
    """
    计算两个序列的皮尔逊相关系数（GPU 加速）
    x, y: shape (seq_len,) 的 PyTorch 张量
    """
    x = x.to(device)
    y = y.to(device)
    mean_x = torch.mean(x)
    mean_y = torch.mean(y)
    xm = x - mean_x
    ym = y - mean_y
    cov_xy = torch.sum(xm * ym)
    std_x = torch.sqrt(torch.sum(xm ** 2))
    std_y = torch.sqrt(torch.sum(ym ** 2))
    corr = cov_xy / (std_x * std_y + 1e-10)  # 避免除以零
    return corr

def create_graph_data(dataset, company_names, seq_len, save_dir, split, corr_threshold=0.7, device='cuda'):
    if not os.path.exists(os.path.join(save_dir, split)):
        os.makedirs(os.path.join(save_dir, split))
    
    num_companies = len(company_names)
    num_windows = 0
    
    # 检查是否有可用的 GPU
    if device == 'cuda' and not torch.cuda.is_available():
        print("警告：未检测到 GPU，使用 CPU 进行计算")
        device = 'cpu'
    
    # 确定最小数据长度
    min_length = min(len(dataset[company]) for company in company_names if not dataset[company].empty)
    if min_length < seq_len + 1:
        print(f"警告：{split} 集数据不足 (min_length={min_length})")
        return 0
    
    # 按行索引生成时间窗口
    for i in range(min_length - seq_len):
        X = []
        Y = []
        valid_companies = []
        close_prices_window = []
        
        # 收集当前窗口的数据
        for j, company in enumerate(company_names):
            df = dataset[company]
            if len(df) < seq_len + 1:
                continue
            
            window_data = df.iloc[i:i+seq_len]
            if len(window_data) == seq_len:
                features = window_data[['Open', 'High', 'Low', 'Close', 'Volume']].values
                X.append(features)
                close_prices_window.append(window_data['Close'].values)
                
                current_close = window_data['Close'].iloc[-1]
                next_data = df.iloc[i+seq_len] if i+seq_len < len(df) else None
                if next_data is not None:
                    next_close = next_data['Close']
                    label = 1 if next_close > current_close else 0
                    Y.append(label)
                    valid_companies.append(j)
        
        # 仅当所有公司数据完整时继续
        if len(X) == num_companies and len(Y) == num_companies:
            # 计算当前窗口的相关性矩阵
            adj_matrix = np.zeros((num_companies, num_companies))
            close_prices_window = np.array(close_prices_window)  # (num_companies, seq_len)
            close_prices_tensor = torch.tensor(close_prices_window, dtype=torch.float32)
            
            for m in range(num_companies):
                for n in range(m + 1, num_companies):
                    if len(close_prices_window[m]) > 1 and len(close_prices_window[n]) > 1:
                        corr = pearsonr_torch(close_prices_tensor[m], close_prices_tensor[n], device)
                        if abs(corr) > corr_threshold:
                            adj_matrix[m, n] = 1
                            adj_matrix[n, m] = 1
            
            # 生成 edge_index
            indices = np.vstack(np.where(adj_matrix > 0))
            edge_index = torch.from_numpy(indices).long()
            
            # 保存图数据
            X = torch.from_numpy(np.array(X, dtype=np.float32))  # (num_companies, seq_len, 5)
            Y = torch.tensor(Y, dtype=torch.long)   # (num_companies,)
            graph_data = {'X': X, 'A': edge_index, 'Y': Y}
            torch.save(graph_data, os.path.join(save_dir, split, f'graph_{num_windows}.pt'))
            num_windows += 1
    
    return num_windows

# 创建并保存图数据
save_dir = './w_5_NASDAQ_graph_data'
seq_len = 5
corr_threshold = 0.7
device = 'cuda' if torch.cuda.is_available() else 'cpu'
train_windows = create_graph_data(train_data, company_names, seq_len, save_dir=save_dir, split='train', corr_threshold=corr_threshold, device=device)
# val_windows = create_graph_data(val_data, company_names, seq_len, save_dir=save_dir, split='val', corr_threshold=corr_threshold, device=device)
# test_windows = create_graph_data(test_data, company_names, seq_len, save_dir=save_dir, split='test', corr_threshold=corr_threshold, device=device)
# print(f"创建了 {train_windows} 个训练图、{val_windows} 个验证图、{test_windows} 个测试图数据文件。")

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GATConv
import os
import time
from sklearn.metrics import f1_score, matthews_corrcoef
import numpy as np

# 检查 GPU 可用性
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

class GATGRUModel(nn.Module):
    def __init__(self, input_dim, gru_hidden_dim, gat_hidden_dim, num_heads, output_dim=2):
        super(GATGRUModel, self).__init__()
        self.gru = nn.GRU(input_dim, gru_hidden_dim, batch_first=True)
        self.gat1 = GATConv(gru_hidden_dim, gat_hidden_dim, heads=num_heads, concat=True)
        self.gat2 = GATConv(gat_hidden_dim * num_heads, gat_hidden_dim, heads=1, concat=True)
        self.fc = nn.Linear(gat_hidden_dim, output_dim)

    def forward(self, x, edge_index):
        gru_out, _ = self.gru(x)
        gru_out = gru_out[:, -1, :]
        gat_out = F.relu(self.gat1(gru_out, edge_index))
        gat_out = self.gat2(gat_out, edge_index)
        out = self.fc(gat_out)
        return out

def train_model(model, save_dir, train_windows, val_windows, test_windows, epochs=50):
    # 将模型移动到 GPU
    model = model.to(device)
    
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.CrossEntropyLoss()
    
    # 加载训练集中第一张图的边索引
    first_graph_data = torch.load(os.path.join(save_dir, 'train', 'graph_0.pt'))
    fixed_edge_index = first_graph_data['A'].to(device)  # 固定边索引并移到 GPU
    
    start_time = time.time()  # 记录训练开始时间
    best_val_accuracy = 0.0  # Track the best validation accuracy
    
    for epoch in range(epochs):
        epoch_start = time.time()  # 记录该 epoch 开始时间

        # 训练
        model.train()
        train_loss, train_accuracy, train_count = 0.0, 0.0, 0
        train_predictions, train_labels = [], []
        
        for i in range(train_windows):
            graph_data = torch.load(os.path.join(save_dir, 'train', f'graph_{i}.pt'))
            X, Y = graph_data['X'], graph_data['Y']
            X, Y = X.to(device), Y.to(device)
            
            optimizer.zero_grad()
            out = model(X, fixed_edge_index)  # 使用固定的边索引
            loss = criterion(out, Y)
            loss.backward()
            optimizer.step()
            
            _, predicted = torch.max(out, 1)
            train_loss += loss.item()
            train_accuracy += (predicted == Y).float().mean().item()
            train_count += 1
            
            train_predictions.extend(predicted.cpu().numpy())
            train_labels.extend(Y.cpu().numpy())
            
        # 验证
        model.eval()
        val_loss, val_accuracy, val_count = 0.0, 0.0, 0
        val_predictions, val_labels = [], []
        
        with torch.no_grad():
            for i in range(val_windows):
                graph_data = torch.load(os.path.join(save_dir, 'val', f'graph_{i}.pt'))
                X, Y = graph_data['X'], graph_data['Y']
                X, Y = X.to(device), Y.to(device)
                
                out = model(X, fixed_edge_index)  # 使用固定的边索引
                loss = criterion(out, Y)
                _, predicted = torch.max(out, 1)
                val_loss += loss.item()
                val_accuracy += (predicted == Y).float().mean().item()
                val_count += 1
                
                val_predictions.extend(predicted.cpu().numpy())
                val_labels.extend(Y.cpu().numpy())
        
        # 平均指标
        avg_train_loss = train_loss / train_count if train_count > 0 else 0
        avg_train_accuracy = train_accuracy / train_count if train_count > 0 else 0
        avg_val_loss = val_loss / val_count if val_count > 0 else 0
        avg_val_accuracy = val_accuracy / val_count if val_count > 0 else 0
        
        # 计算 F1 分数和 MCC
        train_f1 = f1_score(train_labels, train_predictions, average='weighted')
        train_mcc = matthews_corrcoef(train_labels, train_predictions)
        val_f1 = f1_score(val_labels, val_predictions, average='weighted')
        val_mcc = matthews_corrcoef(val_labels, val_predictions)
        
        # 保存最佳模型
        if avg_val_accuracy > best_val_accuracy:
            torch.save(model.state_dict(), 'GAT+GRU_w5_gru64_gat64_head3_static.pt')
            best_val_accuracy = avg_val_accuracy
            
        # 时间统计
        epoch_time = time.time() - epoch_start
        total_time = time.time() - start_time
        
        # 打印指标
        print(f'Epoch {epoch+1}, '
              f'Train Loss: {avg_train_loss:.4f}, Train Acc: {avg_train_accuracy:.4f}, '
              f'Train F1: {train_f1:.4f}, Train MCC: {train_mcc:.4f}, '
              f'Val Loss: {avg_val_loss:.4f}, Val Acc: {avg_val_accuracy:.4f}, '
              f'Val F1: {val_f1:.4f}, Val MCC: {val_mcc:.4f}, '
              f'Epoch Time: {epoch_time:.2f}s, Total Time: {total_time:.2f}s')
    
    print(f'Best Val Accuracy: {best_val_accuracy:.4f}')

# 参数
input_dim = 5  # Open, High, Low, Close, Volume
gru_hidden_dim = 64
gat_hidden_dim = 64
num_heads = 3

save_dir = './w_5_NASDAQ_graph_data'
train_windows = 151
val_windows = 30
test_windows = 35

# 初始化模型
model = GATGRUModel(input_dim, gru_hidden_dim, gat_hidden_dim, num_heads, output_dim=2)

train_model(model, save_dir, train_windows, val_windows, test_windows)
# Out:
# Using device: cuda
# Epoch 1, Train Loss: 0.7023, Train Acc: 0.5154, Train F1: 0.5059, Train MCC: 0.0142, Val Loss: 0.7078, Val Acc: 0.4718, Val F1: 0.3430, Val MCC: 0.0345, Epoch Time: 2.61s, Total Time: 2.61s
# Epoch 2, Train Loss: 0.6990, Train Acc: 0.5084, Train F1: 0.4820, Train MCC: -0.0120, Val Loss: 0.6902, Val Acc: 0.5393, Val F1: 0.3779, Val MCC: 0.0000, Epoch Time: 2.19s, Total Time: 4.80s
# Epoch 3, Train Loss: 0.6950, Train Acc: 0.5215, Train F1: 0.3888, Train MCC: -0.0331, Val Loss: 0.6913, Val Acc: 0.5393, Val F1: 0.3779, Val MCC: 0.0000, Epoch Time: 2.03s, Total Time: 6.83s
# Epoch 4, Train Loss: 0.6937, Train Acc: 0.5304, Train F1: 0.3676, Train MCC: 0.0000, Val Loss: 0.6899, Val Acc: 0.5393, Val F1: 0.3779, Val MCC: 0.0000, Epoch Time: 2.04s, Total Time: 8.88s
# Epoch 5, Train Loss: 0.6928, Train Acc: 0.5323, Train F1: 0.3754, Train MCC: 0.0291, Val Loss: 0.6920, Val Acc: 0.5637, Val F1: 0.5591, Val MCC: 0.1133, Epoch Time: 2.18s, Total Time: 11.06s
# Epoch 6, Train Loss: 0.6963, Train Acc: 0.5141, Train F1: 0.4450, Train MCC: -0.0201, Val Loss: 0.6906, Val Acc: 0.5502, Val F1: 0.4481, Val MCC: 0.0636, Epoch Time: 2.13s, Total Time: 13.18s
# Epoch 7, Train Loss: 0.6927, Train Acc: 0.5303, Train F1: 0.4014, Train MCC: 0.0125, Val Loss: 0.6883, Val Acc: 0.5521, Val F1: 0.4453, Val MCC: 0.0720, Epoch Time: 2.13s, Total Time: 15.32s
# Epoch 8, Train Loss: 0.6915, Train Acc: 0.5375, Train F1: 0.4200, Train MCC: 0.0457, Val Loss: 0.6865, Val Acc: 0.5636, Val F1: 0.4987, Val MCC: 0.1018, Epoch Time: 2.13s, Total Time: 17.44s
# Epoch 9, Train Loss: 0.6915, Train Acc: 0.5373, Train F1: 0.4315, Train MCC: 0.0439, Val Loss: 0.6870, Val Acc: 0.5608, Val F1: 0.4756, Val MCC: 0.0979, Epoch Time: 2.20s, Total Time: 19.64s
# Epoch 10, Train Loss: 0.6905, Train Acc: 0.5414, Train F1: 0.4322, Train MCC: 0.0606, Val Loss: 0.6852, Val Acc: 0.5698, Val F1: 0.5051, Val MCC: 0.1198, Epoch Time: 2.09s, Total Time: 21.73s
# Epoch 11, Train Loss: 0.6914, Train Acc: 0.5400, Train F1: 0.4378, Train MCC: 0.0535, Val Loss: 0.6866, Val Acc: 0.5628, Val F1: 0.4747, Val MCC: 0.1058, Epoch Time: 2.17s, Total Time: 23.90s
# Epoch 12, Train Loss: 0.6905, Train Acc: 0.5413, Train F1: 0.4400, Train MCC: 0.0584, Val Loss: 0.6855, Val Acc: 0.5704, Val F1: 0.4892, Val MCC: 0.1282, Epoch Time: 2.00s, Total Time: 25.89s
# Epoch 13, Train Loss: 0.6897, Train Acc: 0.5418, Train F1: 0.4469, Train MCC: 0.0589, Val Loss: 0.6822, Val Acc: 0.5775, Val F1: 0.5146, Val MCC: 0.1415, Epoch Time: 2.13s, Total Time: 28.02s
# Epoch 14, Train Loss: 0.6882, Train Acc: 0.5478, Train F1: 0.4523, Train MCC: 0.0808, Val Loss: 0.6891, Val Acc: 0.5801, Val F1: 0.5272, Val MCC: 0.1448, Epoch Time: 2.00s, Total Time: 30.02s
# Epoch 15, Train Loss: 0.6881, Train Acc: 0.5478, Train F1: 0.4435, Train MCC: 0.0847, Val Loss: 0.6935, Val Acc: 0.5694, Val F1: 0.5243, Val MCC: 0.1149, Epoch Time: 2.05s, Total Time: 32.07s
# Epoch 16, Train Loss: 0.6874, Train Acc: 0.5440, Train F1: 0.4474, Train MCC: 0.0674, Val Loss: 0.6814, Val Acc: 0.5817, Val F1: 0.5257, Val MCC: 0.1506, Epoch Time: 2.13s, Total Time: 34.20s
# Epoch 17, Train Loss: 0.6862, Train Acc: 0.5483, Train F1: 0.4574, Train MCC: 0.0810, Val Loss: 0.6806, Val Acc: 0.5821, Val F1: 0.5260, Val MCC: 0.1515, Epoch Time: 2.19s, Total Time: 36.39s
# Epoch 18, Train Loss: 0.6886, Train Acc: 0.5451, Train F1: 0.4258, Train MCC: 0.0817, Val Loss: 0.6835, Val Acc: 0.5826, Val F1: 0.5273, Val MCC: 0.1526, Epoch Time: 2.16s, Total Time: 38.54s
# Epoch 19, Train Loss: 0.6865, Train Acc: 0.5466, Train F1: 0.4283, Train MCC: 0.0884, Val Loss: 0.6862, Val Acc: 0.5828, Val F1: 0.5277, Val MCC: 0.1531, Epoch Time: 2.22s, Total Time: 40.76s
# Epoch 20, Train Loss: 0.6864, Train Acc: 0.5477, Train F1: 0.4371, Train MCC: 0.0876, Val Loss: 0.6858, Val Acc: 0.5825, Val F1: 0.5271, Val MCC: 0.1525, Epoch Time: 2.00s, Total Time: 42.76s
# Epoch 21, Train Loss: 0.6868, Train Acc: 0.5478, Train F1: 0.4399, Train MCC: 0.0864, Val Loss: 0.6856, Val Acc: 0.5828, Val F1: 0.5277, Val MCC: 0.1531, Epoch Time: 2.22s, Total Time: 44.99s
# Epoch 22, Train Loss: 0.6866, Train Acc: 0.5456, Train F1: 0.4494, Train MCC: 0.0729, Val Loss: 0.6917, Val Acc: 0.5852, Val F1: 0.5352, Val MCC: 0.1575, Epoch Time: 2.20s, Total Time: 47.19s
# Epoch 23, Train Loss: 0.6851, Train Acc: 0.5492, Train F1: 0.4540, Train MCC: 0.0857, Val Loss: 0.6922, Val Acc: 0.5854, Val F1: 0.5387, Val MCC: 0.1567, Epoch Time: 2.27s, Total Time: 49.46s
# Epoch 24, Train Loss: 0.6859, Train Acc: 0.5492, Train F1: 0.4570, Train MCC: 0.0847, Val Loss: 0.6879, Val Acc: 0.5850, Val F1: 0.5403, Val MCC: 0.1550, Epoch Time: 2.20s, Total Time: 51.66s
# Epoch 25, Train Loss: 0.6853, Train Acc: 0.5524, Train F1: 0.4640, Train MCC: 0.0941, Val Loss: 0.6813, Val Acc: 0.5851, Val F1: 0.5364, Val MCC: 0.1566, Epoch Time: 2.19s, Total Time: 53.85s
# Epoch 26, Train Loss: 0.6849, Train Acc: 0.5521, Train F1: 0.4489, Train MCC: 0.1012, Val Loss: 0.6787, Val Acc: 0.5850, Val F1: 0.5375, Val MCC: 0.1560, Epoch Time: 2.02s, Total Time: 55.87s
# Epoch 27, Train Loss: 0.6851, Train Acc: 0.5502, Train F1: 0.4390, Train MCC: 0.0991, Val Loss: 0.6877, Val Acc: 0.5848, Val F1: 0.5408, Val MCC: 0.1542, Epoch Time: 2.07s, Total Time: 57.94s
# Epoch 28, Train Loss: 0.6849, Train Acc: 0.5502, Train F1: 0.4516, Train MCC: 0.0910, Val Loss: 0.6832, Val Acc: 0.5808, Val F1: 0.5401, Val MCC: 0.1432, Epoch Time: 1.95s, Total Time: 59.89s
# Epoch 29, Train Loss: 0.6859, Train Acc: 0.5468, Train F1: 0.4415, Train MCC: 0.0808, Val Loss: 0.6834, Val Acc: 0.5815, Val F1: 0.5261, Val MCC: 0.1497, Epoch Time: 1.89s, Total Time: 61.79s
# Epoch 30, Train Loss: 0.6863, Train Acc: 0.5496, Train F1: 0.4326, Train MCC: 0.1011, Val Loss: 0.6818, Val Acc: 0.5860, Val F1: 0.5423, Val MCC: 0.1571, Epoch Time: 2.08s, Total Time: 63.87s
# Epoch 31, Train Loss: 0.6857, Train Acc: 0.5518, Train F1: 0.4507, Train MCC: 0.0984, Val Loss: 0.6870, Val Acc: 0.5854, Val F1: 0.5399, Val MCC: 0.1563, Epoch Time: 2.14s, Total Time: 66.01s
# Epoch 32, Train Loss: 0.6862, Train Acc: 0.5503, Train F1: 0.4430, Train MCC: 0.0965, Val Loss: 0.6884, Val Acc: 0.5730, Val F1: 0.5364, Val MCC: 0.1234, Epoch Time: 2.13s, Total Time: 68.13s
# Epoch 33, Train Loss: 0.6852, Train Acc: 0.5468, Train F1: 0.4544, Train MCC: 0.0762, Val Loss: 0.6950, Val Acc: 0.5639, Val F1: 0.5341, Val MCC: 0.1023, Epoch Time: 2.28s, Total Time: 70.41s
# Epoch 34, Train Loss: 0.6838, Train Acc: 0.5525, Train F1: 0.4636, Train MCC: 0.0947, Val Loss: 0.6952, Val Acc: 0.5720, Val F1: 0.5361, Val MCC: 0.1210, Epoch Time: 2.20s, Total Time: 72.61s
# Epoch 35, Train Loss: 0.6836, Train Acc: 0.5554, Train F1: 0.4637, Train MCC: 0.1066, Val Loss: 0.7013, Val Acc: 0.5550, Val F1: 0.5330, Val MCC: 0.0843, Epoch Time: 2.31s, Total Time: 74.92s
# Epoch 36, Train Loss: 0.6838, Train Acc: 0.5558, Train F1: 0.4746, Train MCC: 0.1028, Val Loss: 0.6875, Val Acc: 0.5858, Val F1: 0.5403, Val MCC: 0.1575, Epoch Time: 2.21s, Total Time: 77.13s
# Epoch 37, Train Loss: 0.6900, Train Acc: 0.5380, Train F1: 0.4028, Train MCC: 0.0554, Val Loss: 0.7276, Val Acc: 0.5466, Val F1: 0.5229, Val MCC: 0.0649, Epoch Time: 2.33s, Total Time: 79.46s
# Epoch 38, Train Loss: 0.6887, Train Acc: 0.5449, Train F1: 0.4324, Train MCC: 0.0763, Val Loss: 0.6993, Val Acc: 0.5401, Val F1: 0.5108, Val MCC: 0.0479, Epoch Time: 2.20s, Total Time: 81.66s
# Epoch 39, Train Loss: 0.6882, Train Acc: 0.5475, Train F1: 0.4627, Train MCC: 0.0767, Val Loss: 0.6916, Val Acc: 0.5525, Val F1: 0.5218, Val MCC: 0.0757, Epoch Time: 2.17s, Total Time: 83.83s
# Epoch 40, Train Loss: 0.6853, Train Acc: 0.5518, Train F1: 0.4676, Train MCC: 0.0906, Val Loss: 0.6957, Val Acc: 0.5687, Val F1: 0.5231, Val MCC: 0.1133, Epoch Time: 2.11s, Total Time: 85.94s
# Epoch 41, Train Loss: 0.6839, Train Acc: 0.5503, Train F1: 0.4683, Train MCC: 0.0851, Val Loss: 0.6928, Val Acc: 0.5593, Val F1: 0.5261, Val MCC: 0.0910, Epoch Time: 2.02s, Total Time: 87.96s
# Epoch 42, Train Loss: 0.6838, Train Acc: 0.5598, Train F1: 0.4785, Train MCC: 0.1158, Val Loss: 0.6843, Val Acc: 0.5765, Val F1: 0.5367, Val MCC: 0.1323, Epoch Time: 1.99s, Total Time: 89.95s
# Epoch 43, Train Loss: 0.6856, Train Acc: 0.5538, Train F1: 0.4687, Train MCC: 0.0975, Val Loss: 0.6845, Val Acc: 0.5817, Val F1: 0.5257, Val MCC: 0.1505, Epoch Time: 1.98s, Total Time: 91.93s
# Epoch 44, Train Loss: 0.6842, Train Acc: 0.5559, Train F1: 0.4571, Train MCC: 0.1131, Val Loss: 0.6838, Val Acc: 0.5834, Val F1: 0.5383, Val MCC: 0.1508, Epoch Time: 1.97s, Total Time: 93.90s
# Epoch 45, Train Loss: 0.6839, Train Acc: 0.5553, Train F1: 0.4558, Train MCC: 0.1111, Val Loss: 0.6830, Val Acc: 0.5762, Val F1: 0.5247, Val MCC: 0.1339, Epoch Time: 1.99s, Total Time: 95.90s
# Epoch 46, Train Loss: 0.6831, Train Acc: 0.5581, Train F1: 0.4723, Train MCC: 0.1124, Val Loss: 0.7139, Val Acc: 0.5591, Val F1: 0.5299, Val MCC: 0.0914, Epoch Time: 2.14s, Total Time: 98.04s
# Epoch 47, Train Loss: 0.6833, Train Acc: 0.5553, Train F1: 0.4743, Train MCC: 0.1011, Val Loss: 0.6873, Val Acc: 0.5798, Val F1: 0.5270, Val MCC: 0.1440, Epoch Time: 2.30s, Total Time: 100.33s
# Epoch 48, Train Loss: 0.6818, Train Acc: 0.5629, Train F1: 0.4812, Train MCC: 0.1265, Val Loss: 0.6990, Val Acc: 0.5434, Val F1: 0.5109, Val MCC: 0.0542, Epoch Time: 2.20s, Total Time: 102.53s
# Epoch 49, Train Loss: 0.6817, Train Acc: 0.5567, Train F1: 0.4852, Train MCC: 0.1018, Val Loss: 0.6987, Val Acc: 0.5571, Val F1: 0.5257, Val MCC: 0.0862, Epoch Time: 2.18s, Total Time: 104.72s
# Epoch 50, Train Loss: 0.6813, Train Acc: 0.5581, Train F1: 0.4865, Train MCC: 0.1062, Val Loss: 0.6902, Val Acc: 0.5701, Val F1: 0.5284, Val MCC: 0.1165, Epoch Time: 2.23s, Total Time: 106.94s
# Best Val Accuracy: 0.5860

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GATConv
import os
import time
from sklearn.metrics import f1_score, matthews_corrcoef
import numpy as np

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

class GATGRUModel(nn.Module):
    def __init__(self, input_dim, gru_hidden_dim, gat_hidden_dim, num_heads, output_dim=2):
        super(GATGRUModel, self).__init__()
        self.gru = nn.GRU(input_dim, gru_hidden_dim, batch_first=True)
        self.gat1 = GATConv(gru_hidden_dim, gat_hidden_dim, heads=num_heads, concat=True)
        self.gat2 = GATConv(gat_hidden_dim * num_heads, gat_hidden_dim, heads=1, concat=True)
        self.fc = nn.Linear(gat_hidden_dim, output_dim)

    def forward(self, x, edge_index):
        gru_out, _ = self.gru(x)
        gru_out = gru_out[:, -1, :]
        gat_out = F.relu(self.gat1(gru_out, edge_index))
        gat_out = self.gat2(gat_out, edge_index)
        out = self.fc(gat_out)
        return out

input_dim = 5  # Open, High, Low, Close, Volume
gru_hidden_dim = 64
gat_hidden_dim = 64
num_heads = 3

save_dir = './w_5_NASDAQ_graph_data'
train_windows = 151
val_windows = 30
test_windows = 35

model = GATGRUModel(input_dim, gru_hidden_dim, gat_hidden_dim, num_heads, output_dim=2)
model.load_state_dict(torch.load('GAT+GRU_w5_gru64_gat64_head3_static.pt', map_location=device))
model.to(device)
model.eval()  
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

# 加载训练集中第一张图的边索引
first_graph_data = torch.load(os.path.join(save_dir, 'train', 'graph_0.pt'))
fixed_edge_index = first_graph_data['A'].to(device)  # 固定边索引并移到 GPU

val_loss, val_accuracy, val_count = 0.0, 0.0, 0
val_predictions, val_labels = [], []
with torch.no_grad():
    for i in range(val_windows):
        graph_data = torch.load(os.path.join(save_dir, 'val', f'graph_{i}.pt'))
        X, Y = graph_data['X'], graph_data['Y']
        X, Y = X.to(device), Y.to(device)
        
        out = model(X, fixed_edge_index)  # 使用固定的边索引
        loss = criterion(out, Y)
        _, predicted = torch.max(out, 1)
        val_loss += loss.item()
        val_accuracy += (predicted == Y).float().mean().item()
        val_count += 1
        
        val_predictions.extend(predicted.cpu().numpy())
        val_labels.extend(Y.cpu().numpy())

# 平均指标
avg_val_loss = val_loss / val_count if val_count > 0 else 0
avg_val_accuracy = val_accuracy / val_count if val_count > 0 else 0

# --- Calculate F1-score and MCC ---
val_f1 = f1_score(val_labels, val_predictions, average='weighted')
val_mcc = matthews_corrcoef(val_labels, val_predictions)

# --- Updated print statement with F1 and MCC ---
print(
      f'Val Loss: {avg_val_loss:.4f}, Val Acc: {avg_val_accuracy:.4f}, '
      f'Val F1: {val_f1:.4f}, Val MCC: {val_mcc:.4f} ')
# Out:
# Using device: cuda
# Val Loss: 0.6818, Val Acc: 0.5860, Val F1: 0.5423, Val MCC: 0.1571
